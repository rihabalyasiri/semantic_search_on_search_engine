# %%
import pandas as pd

# %%
file_path = "./xlsx/experiment_results.xlsx"

# %%
df = pd.read_excel(file_path)

# %%
df
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 0                 1                Yes    German Semantic Comparator
# 1                 2                Yes    German Semantic Comparator
# 2                 3                Yes    German Semantic Comparator
# 3                 4                Yes    German Semantic Comparator
# 4                 5                Yes    German Semantic Comparator
# ..              ...                ...                           ...
# 118              39                 No  MultiLang Efficient Embedder
# 119              40                 No  MultiLang Efficient Embedder
# 120               1                NaN                      baseline
# 121               2                NaN                      baseline
# 122               3                NaN                      baseline
#
#          Algorithm Type                                           Features  \
# ...

# %%
specific_numbers = [5, 10, 15, 20, 25, 30, 35, 40]

df_specific = df[df['Experiment no.'].isin(specific_numbers)]
df_specific
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 4                 5                Yes    German Semantic Comparator
# 9                10                Yes    German Semantic Comparator
# 14               15                Yes  MultiLang Efficient Embedder
# 19               20                Yes  MultiLang Efficient Embedder
# 24               25                 No    German Semantic Comparator
# 29               30                 No    German Semantic Comparator
# 34               35                 No  MultiLang Efficient Embedder
# 39               40                 No  MultiLang Efficient Embedder
# 44                5                Yes    German Semantic Comparator
# 49               10                Yes    German Semantic Comparator
# 54               15                Yes  MultiLang Efficient Embedder
# 59               20                Yes  MultiLang Efficient Embedder
# 64               25                 No    German Semantic Comparator
# ...

# %%
df_filtered = df[(df['Data Preprocessing'] == 'Yes') & (df['query'] == 'wein kaufen')]
df_filtered = df_filtered.drop(['Total no. of Relevant in db', 'Relevant no. of 25', 'Relevant no. of 10', 'Precision@10', 'Recall@10', 'Precision@25', 'Recall@25', 'query'], axis=1)

# %%
df_filtered
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 0                1                Yes    German Semantic Comparator
# 1                2                Yes    German Semantic Comparator
# 2                3                Yes    German Semantic Comparator
# 3                4                Yes    German Semantic Comparator
# 4                5                Yes    German Semantic Comparator
# 5                6                Yes    German Semantic Comparator
# 6                7                Yes    German Semantic Comparator
# 7                8                Yes    German Semantic Comparator
# 8                9                Yes    German Semantic Comparator
# 9               10                Yes    German Semantic Comparator
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# ...

# %%
df_without_baseline = df.iloc[:-3]
df_without_baseline.describe()
# Out:
#        Experiment no.  Total no. of Relevant in db  Relevant no. of 25  \
# count      120.000000                   120.000000          120.000000
# mean        20.500000                    85.458333           12.575000
# std         11.591797                    42.073344            8.456177
# min          1.000000                    48.000000            0.000000
# 25%         10.750000                    48.000000            3.000000
# 50%         20.500000                    63.000000           13.500000
# 75%         30.250000                   143.000000           20.000000
# max         40.000000                   143.000000           25.000000
#
#        Relevant no. of 10  Precision@10   Recall@10  Precision@25   Recall@25
# count          120.000000    105.000000  105.000000    105.000000  105.000000
# mean             4.950000      0.513333    0.075902      0.517333    0.188097
# std              3.514316      0.332839    0.052760      0.322598    0.125548
# ...

# %% [markdown]
# # Plotting in bars the whole relevants for the whole Experiments for specific Query

# %%
df_without_baseline[(df_without_baseline['query'] == 'wein kaufen') ].plot(x='Experiment no.', y='Relevant no. of 25', kind='bar')
# Out:
# <Axes: xlabel='Experiment no.'>

# %%
df[(df['query'] == 'schnäppchen flüge') ].plot(x='Experiment no.', y='Relevant no. of 25', kind='bar')
# Out:
# <Axes: xlabel='Experiment no.'>

# %%
df_without_baseline[(df_without_baseline['query'] == 'günstiger mobilfunktarif') ].plot(x='Experiment no.', y='Relevant no. of 25', kind='bar')
# Out:
# <Axes: xlabel='Experiment no.'>

# %% [markdown]
# # Results for Query ( Wein kaufen)

# %% [markdown]
# ### Average of relevant results with data cleaning @10

# %%
data = df_without_baseline[(df_without_baseline['Data Preprocessing'] == 'Yes')  & (df_without_baseline['query'] == 'wein kaufen')]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 0                1                Yes    German Semantic Comparator
# 1                2                Yes    German Semantic Comparator
# 2                3                Yes    German Semantic Comparator
# 3                4                Yes    German Semantic Comparator
# 4                5                Yes    German Semantic Comparator
# 5                6                Yes    German Semantic Comparator
# 6                7                Yes    German Semantic Comparator
# 7                8                Yes    German Semantic Comparator
# 8                9                Yes    German Semantic Comparator
# 9               10                Yes    German Semantic Comparator
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 5.05

# %% [markdown]
# ### Average of relevant results with data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 13.2

# %% [markdown]
# ### Average of relevant results without data cleaning @10

# %%
data = df_without_baseline[(df_without_baseline['Data Preprocessing'] == 'No') & (df_without_baseline['query'] == 'wein kaufen') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 20              21                 No    German Semantic Comparator
# 21              22                 No    German Semantic Comparator
# 22              23                 No    German Semantic Comparator
# 23              24                 No    German Semantic Comparator
# 24              25                 No    German Semantic Comparator
# 25              26                 No    German Semantic Comparator
# 26              27                 No    German Semantic Comparator
# 27              28                 No    German Semantic Comparator
# 28              29                 No    German Semantic Comparator
# 29              30                 No    German Semantic Comparator
# 30              31                 No  MultiLang Efficient Embedder
# 31              32                 No  MultiLang Efficient Embedder
# 32              33                 No  MultiLang Efficient Embedder
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.6

# %% [markdown]
# ### Average of relevant results without data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 18.35

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @10

# %%
data = df_without_baseline[(df_without_baseline['Model Type'] == 'German Semantic Comparator') & (df_without_baseline['query'] == 'wein kaufen') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                  Model Type  \
# 0                1                Yes  German Semantic Comparator
# 1                2                Yes  German Semantic Comparator
# 2                3                Yes  German Semantic Comparator
# 3                4                Yes  German Semantic Comparator
# 4                5                Yes  German Semantic Comparator
# 5                6                Yes  German Semantic Comparator
# 6                7                Yes  German Semantic Comparator
# 7                8                Yes  German Semantic Comparator
# 8                9                Yes  German Semantic Comparator
# 9               10                Yes  German Semantic Comparator
# 20              21                 No  German Semantic Comparator
# 21              22                 No  German Semantic Comparator
# 22              23                 No  German Semantic Comparator
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.45

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 19.1

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @10

# %%
data = df_without_baseline[(df_without_baseline['Model Type'] == 'MultiLang Efficient Embedder') & (df_without_baseline['query'] == 'wein kaufen') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# 13              14                Yes  MultiLang Efficient Embedder
# 14              15                Yes  MultiLang Efficient Embedder
# 15              16                Yes  MultiLang Efficient Embedder
# 16              17                Yes  MultiLang Efficient Embedder
# 17              18                Yes  MultiLang Efficient Embedder
# 18              19                Yes  MultiLang Efficient Embedder
# 19              20                Yes  MultiLang Efficient Embedder
# 30              31                 No  MultiLang Efficient Embedder
# 31              32                 No  MultiLang Efficient Embedder
# 32              33                 No  MultiLang Efficient Embedder
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 5.2

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 12.45

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @10

# %%
data = df_without_baseline[(df_without_baseline['Algorithm Type'] == 'Cosine Similarity') & (df_without_baseline['query'] == 'wein kaufen')]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 0                1                Yes    German Semantic Comparator
# 1                2                Yes    German Semantic Comparator
# 2                3                Yes    German Semantic Comparator
# 3                4                Yes    German Semantic Comparator
# 4                5                Yes    German Semantic Comparator
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# 13              14                Yes  MultiLang Efficient Embedder
# 14              15                Yes  MultiLang Efficient Embedder
# 20              21                 No    German Semantic Comparator
# 21              22                 No    German Semantic Comparator
# 22              23                 No    German Semantic Comparator
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.15

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 17.1

# %%
data = df_without_baseline[(df_without_baseline['Algorithm Type'] == 'Euclidean Distance') & (df_without_baseline['query'] == 'wein kaufen')]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 5                6                Yes    German Semantic Comparator
# 6                7                Yes    German Semantic Comparator
# 7                8                Yes    German Semantic Comparator
# 8                9                Yes    German Semantic Comparator
# 9               10                Yes    German Semantic Comparator
# 15              16                Yes  MultiLang Efficient Embedder
# 16              17                Yes  MultiLang Efficient Embedder
# 17              18                Yes  MultiLang Efficient Embedder
# 18              19                Yes  MultiLang Efficient Embedder
# 19              20                Yes  MultiLang Efficient Embedder
# 25              26                 No    German Semantic Comparator
# 26              27                 No    German Semantic Comparator
# 27              28                 No    German Semantic Comparator
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 5.5

# %%
data['Relevant no. of 25'].mean()
# Out:
# 14.45

# %%
data = df_without_baseline[(df_without_baseline['Algorithm Type'] == 'Cosine Similarity') 
                   & (df_without_baseline['Data Preprocessing'] == 'No') 
                   & (df_without_baseline['Model Type'] == 'German Semantic Comparator') 
                   & (df_without_baseline['query'] == 'wein kaufen')]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                  Model Type  \
# 20              21                 No  German Semantic Comparator
# 21              22                 No  German Semantic Comparator
# 22              23                 No  German Semantic Comparator
# 23              24                 No  German Semantic Comparator
# 24              25                 No  German Semantic Comparator
#
#        Algorithm Type                                           Features  \
# 20  Cosine Similarity                                          body_text
# 21  Cosine Similarity                  body_text, advertiser domain name
# 22  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 23  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 24  Cosine Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.6

# %%
data['Relevant no. of 25'].mean()
# Out:
# 19.6

# %% [markdown]
# # Results for Query ( schnäppchen Flüge)

# %% [markdown]
# ### Average of relevant results with data cleaning @10

# %%
data = df_without_baseline[(df_without_baseline['Data Preprocessing'] == 'Yes') & (df_without_baseline['query'] == 'schnäppchen flüge') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 80               1                Yes    German Semantic Comparator
# 81               2                Yes    German Semantic Comparator
# 82               3                Yes    German Semantic Comparator
# 83               4                Yes    German Semantic Comparator
# 84               5                Yes    German Semantic Comparator
# 85               6                Yes    German Semantic Comparator
# 86               7                Yes    German Semantic Comparator
# 87               8                Yes    German Semantic Comparator
# 88               9                Yes    German Semantic Comparator
# 89              10                Yes    German Semantic Comparator
# 90              11                Yes  MultiLang Efficient Embedder
# 91              12                Yes  MultiLang Efficient Embedder
# 92              13                Yes  MultiLang Efficient Embedder
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.85

# %% [markdown]
# ### Average of relevant results with data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 12.3

# %% [markdown]
# ### Average of relevant results without data cleaning @10

# %%
data = df_without_baseline[(df_without_baseline['Data Preprocessing'] == 'No') & (df_without_baseline['query'] == 'schnäppchen flüge') ]

# %%
data
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 100              21                 No    German Semantic Comparator
# 101              22                 No    German Semantic Comparator
# 102              23                 No    German Semantic Comparator
# 103              24                 No    German Semantic Comparator
# 104              25                 No    German Semantic Comparator
# 105              26                 No    German Semantic Comparator
# 106              27                 No    German Semantic Comparator
# 107              28                 No    German Semantic Comparator
# 108              29                 No    German Semantic Comparator
# 109              30                 No    German Semantic Comparator
# 110              31                 No  MultiLang Efficient Embedder
# 111              32                 No  MultiLang Efficient Embedder
# 112              33                 No  MultiLang Efficient Embedder
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.35

# %% [markdown]
# ### Average of relevant results without data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 11.25

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @10

# %%
data = df_without_baseline[(df_without_baseline['Model Type'] == 'German Semantic Comparator') & (df_without_baseline['query'] == 'schnäppchen flüge') ]

# %%
data
# Out:
#      Experiment no. Data Preprocessing                  Model Type  \
# 80                1                Yes  German Semantic Comparator
# 81                2                Yes  German Semantic Comparator
# 82                3                Yes  German Semantic Comparator
# 83                4                Yes  German Semantic Comparator
# 84                5                Yes  German Semantic Comparator
# 85                6                Yes  German Semantic Comparator
# 86                7                Yes  German Semantic Comparator
# 87                8                Yes  German Semantic Comparator
# 88                9                Yes  German Semantic Comparator
# 89               10                Yes  German Semantic Comparator
# 100              21                 No  German Semantic Comparator
# 101              22                 No  German Semantic Comparator
# 102              23                 No  German Semantic Comparator
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 9.0

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 22.2

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @10

# %%
data = df_without_baseline[(df_without_baseline['Model Type'] == 'MultiLang Efficient Embedder') & (df_without_baseline['query'] == 'schnäppchen flüge') ]

# %%
data
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 90               11                Yes  MultiLang Efficient Embedder
# 91               12                Yes  MultiLang Efficient Embedder
# 92               13                Yes  MultiLang Efficient Embedder
# 93               14                Yes  MultiLang Efficient Embedder
# 94               15                Yes  MultiLang Efficient Embedder
# 95               16                Yes  MultiLang Efficient Embedder
# 96               17                Yes  MultiLang Efficient Embedder
# 97               18                Yes  MultiLang Efficient Embedder
# 98               19                Yes  MultiLang Efficient Embedder
# 99               20                Yes  MultiLang Efficient Embedder
# 110              31                 No  MultiLang Efficient Embedder
# 111              32                 No  MultiLang Efficient Embedder
# 112              33                 No  MultiLang Efficient Embedder
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 0.2

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 1.35

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @10

# %%
data = df_without_baseline[(df_without_baseline['Algorithm Type'] == 'Cosine Similarity') & (df_without_baseline['query'] == 'schnäppchen flüge') ]

# %%
data
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 80                1                Yes    German Semantic Comparator
# 81                2                Yes    German Semantic Comparator
# 82                3                Yes    German Semantic Comparator
# 83                4                Yes    German Semantic Comparator
# 84                5                Yes    German Semantic Comparator
# 90               11                Yes  MultiLang Efficient Embedder
# 91               12                Yes  MultiLang Efficient Embedder
# 92               13                Yes  MultiLang Efficient Embedder
# 93               14                Yes  MultiLang Efficient Embedder
# 94               15                Yes  MultiLang Efficient Embedder
# 100              21                 No    German Semantic Comparator
# 101              22                 No    German Semantic Comparator
# 102              23                 No    German Semantic Comparator
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.6

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 11.85

# %% [markdown]
# ### Average of relevant results with Euclidean Distance@10

# %%
data = df_without_baseline[(df_without_baseline['Algorithm Type'] == 'Euclidean Distance') & (df_without_baseline['query'] == 'schnäppchen flüge') ]

# %%
data
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 85                6                Yes    German Semantic Comparator
# 86                7                Yes    German Semantic Comparator
# 87                8                Yes    German Semantic Comparator
# 88                9                Yes    German Semantic Comparator
# 89               10                Yes    German Semantic Comparator
# 95               16                Yes  MultiLang Efficient Embedder
# 96               17                Yes  MultiLang Efficient Embedder
# 97               18                Yes  MultiLang Efficient Embedder
# 98               19                Yes  MultiLang Efficient Embedder
# 99               20                Yes  MultiLang Efficient Embedder
# 105              26                 No    German Semantic Comparator
# 106              27                 No    German Semantic Comparator
# 107              28                 No    German Semantic Comparator
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.6

# %% [markdown]
# ### Average of relevant results with Euclidean Distance @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 11.7

# %% [markdown]
# # Results for Query ( günstiger Mobilfunktarif)

# %% [markdown]
# ### Average of relevant results with data cleaning @10

# %%
data = df_without_baseline[(df_without_baseline['Data Preprocessing'] == 'Yes') & (df_without_baseline['query'] == 'günstiger mobilfunktarif') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 40               1                Yes    German Semantic Comparator
# 41               2                Yes    German Semantic Comparator
# 42               3                Yes    German Semantic Comparator
# 43               4                Yes    German Semantic Comparator
# 44               5                Yes    German Semantic Comparator
# 45               6                Yes    German Semantic Comparator
# 46               7                Yes    German Semantic Comparator
# 47               8                Yes    German Semantic Comparator
# 48               9                Yes    German Semantic Comparator
# 49              10                Yes    German Semantic Comparator
# 50              11                Yes  MultiLang Efficient Embedder
# 51              12                Yes  MultiLang Efficient Embedder
# 52              13                Yes  MultiLang Efficient Embedder
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 2.6

# %% [markdown]
# ### Average of relevant results with data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 5.65

# %% [markdown]
# ### Average of relevant results without data cleaning @10

# %%
data = df_without_baseline[(df_without_baseline['Data Preprocessing'] == 'No') & (df_without_baseline['query'] == 'günstiger mobilfunktarif') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 60              21                 No    German Semantic Comparator
# 61              22                 No    German Semantic Comparator
# 62              23                 No    German Semantic Comparator
# 63              24                 No    German Semantic Comparator
# 64              25                 No    German Semantic Comparator
# 65              26                 No    German Semantic Comparator
# 66              27                 No    German Semantic Comparator
# 67              28                 No    German Semantic Comparator
# 68              29                 No    German Semantic Comparator
# 69              30                 No    German Semantic Comparator
# 70              31                 No  MultiLang Efficient Embedder
# 71              32                 No  MultiLang Efficient Embedder
# 72              33                 No  MultiLang Efficient Embedder
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.25

# %% [markdown]
# ### Average of relevant results without data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 14.7

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @10

# %%
data = df_without_baseline[(df_without_baseline['Model Type'] == 'German Semantic Comparator') & (df_without_baseline['query'] == 'günstiger mobilfunktarif') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                  Model Type  \
# 40               1                Yes  German Semantic Comparator
# 41               2                Yes  German Semantic Comparator
# 42               3                Yes  German Semantic Comparator
# 43               4                Yes  German Semantic Comparator
# 44               5                Yes  German Semantic Comparator
# 45               6                Yes  German Semantic Comparator
# 46               7                Yes  German Semantic Comparator
# 47               8                Yes  German Semantic Comparator
# 48               9                Yes  German Semantic Comparator
# 49              10                Yes  German Semantic Comparator
# 60              21                 No  German Semantic Comparator
# 61              22                 No  German Semantic Comparator
# 62              23                 No  German Semantic Comparator
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.25

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 14.25

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @10

# %%
data = df_without_baseline[(df_without_baseline['Model Type'] == 'MultiLang Efficient Embedder') & (df_without_baseline['query'] == 'günstiger mobilfunktarif') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 50              11                Yes  MultiLang Efficient Embedder
# 51              12                Yes  MultiLang Efficient Embedder
# 52              13                Yes  MultiLang Efficient Embedder
# 53              14                Yes  MultiLang Efficient Embedder
# 54              15                Yes  MultiLang Efficient Embedder
# 55              16                Yes  MultiLang Efficient Embedder
# 56              17                Yes  MultiLang Efficient Embedder
# 57              18                Yes  MultiLang Efficient Embedder
# 58              19                Yes  MultiLang Efficient Embedder
# 59              20                Yes  MultiLang Efficient Embedder
# 70              31                 No  MultiLang Efficient Embedder
# 71              32                 No  MultiLang Efficient Embedder
# 72              33                 No  MultiLang Efficient Embedder
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 2.6

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 6.1

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @10

# %%
data = df_without_baseline[(df_without_baseline['Algorithm Type'] == 'Cosine Similarity') & (df_without_baseline['query'] == 'günstiger mobilfunktarif') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 40               1                Yes    German Semantic Comparator
# 41               2                Yes    German Semantic Comparator
# 42               3                Yes    German Semantic Comparator
# 43               4                Yes    German Semantic Comparator
# 44               5                Yes    German Semantic Comparator
# 50              11                Yes  MultiLang Efficient Embedder
# 51              12                Yes  MultiLang Efficient Embedder
# 52              13                Yes  MultiLang Efficient Embedder
# 53              14                Yes  MultiLang Efficient Embedder
# 54              15                Yes  MultiLang Efficient Embedder
# 60              21                 No    German Semantic Comparator
# 61              22                 No    German Semantic Comparator
# 62              23                 No    German Semantic Comparator
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.5

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 10.35

# %% [markdown]
# ### Average of relevant results with Euclidean Distance@10

# %%
data = df_without_baseline[(df_without_baseline['Algorithm Type'] == 'Euclidean Distance') & (df_without_baseline['query'] == 'günstiger mobilfunktarif') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 45               6                Yes    German Semantic Comparator
# 46               7                Yes    German Semantic Comparator
# 47               8                Yes    German Semantic Comparator
# 48               9                Yes    German Semantic Comparator
# 49              10                Yes    German Semantic Comparator
# 55              16                Yes  MultiLang Efficient Embedder
# 56              17                Yes  MultiLang Efficient Embedder
# 57              18                Yes  MultiLang Efficient Embedder
# 58              19                Yes  MultiLang Efficient Embedder
# 59              20                Yes  MultiLang Efficient Embedder
# 65              26                 No    German Semantic Comparator
# 66              27                 No    German Semantic Comparator
# 67              28                 No    German Semantic Comparator
# ...

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.35

# %% [markdown]
# ### Average of relevant results with Faiss Similarity@25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 10.0

# %% [markdown]
# # Precision-Recall-Curve Plot

# %%
data = df_without_baseline[(df_without_baseline['query'] == 'schnäppchen flüge') ]

# %%
data
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 80                1                Yes    German Semantic Comparator
# 81                2                Yes    German Semantic Comparator
# 82                3                Yes    German Semantic Comparator
# 83                4                Yes    German Semantic Comparator
# 84                5                Yes    German Semantic Comparator
# 85                6                Yes    German Semantic Comparator
# 86                7                Yes    German Semantic Comparator
# 87                8                Yes    German Semantic Comparator
# 88                9                Yes    German Semantic Comparator
# 89               10                Yes    German Semantic Comparator
# 90               11                Yes  MultiLang Efficient Embedder
# 91               12                Yes  MultiLang Efficient Embedder
# 92               13                Yes  MultiLang Efficient Embedder
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
precision_baseline = 0.44 # wein kaufen at 25
recall_baseline = 0.17 # wein kaufen at 25

# %%
precision_semantic_search = data['Precision@25'].to_numpy()
recall_semantic_search = data['Recall@25'].to_numpy()

# %%
recall_semantic_search
# Out:
# array([0.16083916, 0.16783217, 0.17482517, 0.13986014,        nan,
#        0.16083916, 0.17482517, 0.17482517, 0.14685315,        nan,
#        0.00699301, 0.02097902, 0.01398601, 0.01398601,        nan,
#        0.        , 0.01398601, 0.        , 0.00699301,        nan,
#        0.1048951 , 0.16083916, 0.16783217, 0.11888112,        nan,
#        0.1048951 , 0.16083916, 0.16783217, 0.12587413,        nan,
#        0.02797203, 0.01398601, 0.00699301, 0.01398601,        nan,
#        0.02097902, 0.00699301, 0.00699301, 0.01398601,        nan])

# %%
precision_semantic_search
# Out:
# array([0.92, 0.96, 1.  , 0.8 ,  nan, 0.92, 1.  , 1.  , 0.84,  nan, 0.04,
#        0.12, 0.08, 0.08,  nan, 0.  , 0.08, 0.  , 0.04,  nan, 0.6 , 0.92,
#        0.96, 0.68,  nan, 0.6 , 0.92, 0.96, 0.72,  nan, 0.16, 0.08, 0.04,
#        0.08,  nan, 0.12, 0.04, 0.04, 0.08,  nan])

# %%
plt.figure(figsize=(8, 6))
plt.plot(recall_semantic_search, precision_semantic_search, label='Semantic Search', marker='o')

plt.axhline(y=precision_baseline, color='red', linestyle='-', label='Baseline Elasticsearch')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve Comparison')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Scatter Plot for "Wein Kaufen" with Experiment no. 25 and Cosine Similarity

# %%
import json
import pandas as pd

# Path to your JSON file
file_path = './data/Experiment_25_cosine_similarity.json'

# Load JSON data from file
with open(file_path, 'r') as file:
    data1 = json.load(file)

# %%
import matplotlib.pyplot as plt1
import random


# Extracting data for the plot
x_values = []  # This will store cosine similarity values
y_values = []  # This will store random values for scattering
colors = []    # This will store color values

max_similarity = 0

for obj in data1:
    cosine_similarity = obj.get('similarity', 0)
    wein_kaufen = obj['wein_kaufen']
    max_similarity = max(max_similarity, cosine_similarity) 
    x_values.append(cosine_similarity)
    y_values.append(random.uniform(0, 1) if wein_kaufen else random.uniform(-1, 0))  # Random values for true/false
    colors.append('green' if wein_kaufen else 'blue')  # Yellow for "wein_kaufen" = true, blue for false

# Add the specific query with a large red circle
x_query = [max_similarity]  # Maximum similarity value
y_query = [random.uniform(0, 1)]

# Creating the scatter plot
plt1.figure(figsize=(10, 6))
plt1.scatter(x_values, y_values, c=colors, label='relevant Ads')
plt1.scatter(x_query, y_query, c='red', s=100, label='Query "wein kaufen"')  # Larger red circle for the specific query
plt1.xlabel('Cosine Similarity', fontsize=20)
plt1.ylabel('Random Scatter', fontsize=20)
plt1.title('Scatter Plot for "Wein Kaufen" Query', fontsize=20)
plt1.legend()
plt1.grid(True)
#plt1.show()

# %% [markdown]
# # Scatter Plot for "Wein Kaufen" with Experiment no. 21 and Cosine Similarity

# %%
import json
import pandas as pd

# Path to your JSON file
file_path = './data/Experiment_21_cosine_similarity.json'

# Load JSON data from file
with open(file_path, 'r') as file:
    data1 = json.load(file)

# %%
import matplotlib.pyplot as plt1
import random


# Extracting data for the plot
x_values = []  # This will store cosine similarity values
y_values = []  # This will store random values for scattering
colors = []    # This will store color values

max_similarity = 0

for obj in data1:
    cosine_similarity = obj.get('similarity', 0)
    wein_kaufen = obj['wein_kaufen']
    max_similarity = max(max_similarity, cosine_similarity) 
    x_values.append(cosine_similarity)
    y_values.append(random.uniform(0, 1) if wein_kaufen else random.uniform(-1, 0))  # Random values for true/false
    colors.append('green' if wein_kaufen else 'blue')  # Yellow for "wein_kaufen" = true, blue for false

# Add the specific query with a large red circle
x_query = [max_similarity]  # Maximum similarity value
y_query = [random.uniform(0, 1)]

# Creating the scatter plot
plt1.figure(figsize=(10, 6))
plt1.scatter(x_values, y_values, c=colors, label='relevant Ads')
plt1.scatter(x_query, y_query, c='red', s=100, label='Query "wein kaufen"')  # Larger red circle for the specific query
plt1.xlabel('Cosine Similarity', fontsize=20)
plt1.ylabel('Random Scatter', fontsize=20)
plt1.title('Scatter Plot for "Wein Kaufen" Query', fontsize=20)
plt1.legend()
plt1.grid(True)
#plt1.show()

# %% [markdown]
# # Scatter Plot for "Wein Kaufen" with Experiment no. 26 and Euclidean Distance

# %%
import json

# Path to your JSON file
file_path = './data/Experiment_26_euclidean_distance.json'

# Load JSON data from file
with open(file_path, 'r') as file:
    data2 = json.load(file)

# %%
import matplotlib.pyplot as plt2
import random


# Extracting data for the plot
x_wein_kaufen = []  # Distances for "wein_kaufen" = true
x_other_ads = []  # Distances for "wein_kaufen" = false
y_wein_kaufen = []  # Y-values for "wein_kaufen" = true (for scattering)
y_other_ads = []    # This will store color values

min_distance = float('inf')

for obj in data2:
    distance = obj.get('similarity', 0)
    min_distance = min(min_distance, distance)
    wein_kaufen = obj['wein_kaufen']

    if wein_kaufen:
        x_wein_kaufen.append(distance)
        y_wein_kaufen.append(random.uniform(0, 1))  # Random scatter close to 0
    else:
        x_other_ads.append(distance)
        y_other_ads.append(random.uniform(-1, 0))

# Add the specific query
x_query = [min_distance]
y_query = [random.uniform(0, 1)]  # Place it centrally on the Y-axis

# Plotting
plt2.figure(figsize=(10, 6))
plt2.scatter(x_wein_kaufen, y_wein_kaufen, color='green', label='relevant Ads')
plt2.scatter(x_other_ads, y_other_ads, color='blue', label='not relevant Ads')
plt2.scatter(x_query, y_query, color='red', s=100, label='Query "Wein Kaufen"', marker='*')  # Star marker for the query

plt2.xlabel('Euclidean Distance', fontsize=20)
plt2.ylabel('Random Scatter', fontsize=20)
plt2.title('Scatter Plot for "Wein Kaufen" Query', fontsize=20)
plt2.legend()
plt2.grid(True)
plt2.show()

# %% [markdown]
# # Scatter Plot for "Wein Kaufen" with Experiment no. 30 and Euclidean Distance

# %%
import json

# Path to your JSON file
file_path = './data/Experiment_30_euclidean_distance.json'

# Load JSON data from file
with open(file_path, 'r') as file:
    data3 = json.load(file)

# %%
import matplotlib.pyplot as plt3
import random

# Extracting data for the plot
x_wein_kaufen = []  # Distances for "wein_kaufen" = true
x_other_ads = []  # Distances for "wein_kaufen" = false
y_wein_kaufen = []  # Y-values for "wein_kaufen" = true (for scattering)
y_other_ads = []    # This will store color values

min_distance = float('inf')

for obj in data3:
    distance = obj.get('similarity', 0)
    min_distance = min(min_distance, distance)
    wein_kaufen = obj['wein_kaufen']

    if wein_kaufen:
        x_wein_kaufen.append(distance)
        y_wein_kaufen.append(random.uniform(0, 1))  # Random scatter close to 0
    else:
        x_other_ads.append(distance)
        y_other_ads.append(random.uniform(-1, 0))

# Add the specific query
x_query = [min_distance]
y_query = [random.uniform(0, 1)]  # Place it centrally on the Y-axis

# Plotting
plt3.figure(figsize=(10, 6))
plt3.scatter(x_wein_kaufen, y_wein_kaufen, color='green', label='relevant Ads')
plt3.scatter(x_other_ads, y_other_ads, color='blue', label='not relevant Ads')
plt3.scatter(x_query, y_query, color='red', s=100, label='Query "Wein Kaufen"', marker='*')  # Star marker for the query

plt3.xlabel('Euclidean Distance', fontsize=20)  # Increase the font size of x-axis label
plt3.ylabel('Random Scatter', fontsize=20)
plt3.title('Scatter Plot for "Wein Kaufen" Query', fontsize=20)
plt3.xticks(fontsize=12)  # Increase the font size of x-axis ticks
plt3.legend()
plt3.grid(True)
plt3.show()

# %% [markdown]
# # plot how the data cleaning effects on the relevant results

# %%
import matplotlib.pyplot as plt
data = df_without_baseline[(df_without_baseline['query'] == 'wein kaufen') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 0                1                Yes    German Semantic Comparator
# 1                2                Yes    German Semantic Comparator
# 2                3                Yes    German Semantic Comparator
# 3                4                Yes    German Semantic Comparator
# 4                5                Yes    German Semantic Comparator
# 5                6                Yes    German Semantic Comparator
# 6                7                Yes    German Semantic Comparator
# 7                8                Yes    German Semantic Comparator
# 8                9                Yes    German Semantic Comparator
# 9               10                Yes    German Semantic Comparator
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# ...

# %%
aggregated_data_at_25 = data.groupby('Data Preprocessing')['Relevant no. of 25'].mean()  
aggregated_data_at_10 = data.groupby('Data Preprocessing')['Relevant no. of 10'].mean()  
df_25 = aggregated_data_at_25.reset_index(name='Relevant no. of 25')
df_10 = aggregated_data_at_10.reset_index(name='Relevant no. of 10')

# Merge the two DataFrames on the 'Data Preprocessing' column
merged_data = pd.merge(df_25, df_10, on='Data Preprocessing')

# Plotting
ax = merged_data.plot(x='Data Preprocessing', y='Relevant no. of 25', kind='bar', color='blue', position=0, width=0.4, label='Relevant no. of 25')
merged_data.plot(x='Data Preprocessing', y='Relevant no. of 10', kind='bar', color='red', position=1, width=0.4, label='Relevant no. of 10', ax=ax)

# Customizing the plot
plt.xlabel('Data Preprocessing')
plt.ylabel('Average Relevant Number')
plt.title('Impact of Data Preprocessing on Relevant Ads')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
aggregated_data_at_25 = data.groupby('Model Type')['Relevant no. of 25'].mean()  # or use another function like mean() if more appropriate
aggregated_data_at_10 = data.groupby('Model Type')['Relevant no. of 10'].mean()  # or use another function like mean() if more appropriate

df_25 = aggregated_data_at_25.reset_index(name='Relevant no. of 25')
df_10 = aggregated_data_at_10.reset_index(name='Relevant no. of 10')

# Merge the two DataFrames on the 'Model Type' column
merged_data = pd.merge(df_25, df_10, on='Model Type')

# Plotting
ax = merged_data.plot(x='Model Type', y='Relevant no. of 25', kind='bar', color='blue', position=0, width=0.4, label='Relevant no. of 25')
merged_data.plot(x='Model Type', y='Relevant no. of 10', kind='bar', color='red', position=1, width=0.4, label='Relevant no. of 10', ax=ax)

# Customizing the plot
plt.xlabel('Model Type')
plt.ylabel('Average Relevant Number')
plt.title('Impact of Model Type on Relevant Ads')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
aggregated_data_at_25 = data.groupby('Algorithm Type')['Relevant no. of 25'].mean()  # or use another function like mean() if more appropriate
aggregated_data_at_10 = data.groupby('Algorithm Type')['Relevant no. of 10'].mean()  # or use another function like mean() if more appropriate

df_25 = aggregated_data_at_25.reset_index(name='Relevant no. of 25')
df_10 = aggregated_data_at_10.reset_index(name='Relevant no. of 10')

# Merge the two DataFrames on the 'Algorithm Type' column
merged_data = pd.merge(df_25, df_10, on='Algorithm Type')

# Plotting
ax = merged_data.plot(x='Algorithm Type', y='Relevant no. of 25', kind='bar', color='blue', position=0, width=0.4, label='Relevant no. of 25')
merged_data.plot(x='Algorithm Type', y='Relevant no. of 10', kind='bar', color='red', position=1, width=0.4, label='Relevant no. of 10', ax=ax)

# Customizing the plot
plt.xlabel('Algorithm Type')
plt.ylabel('Average Relevant Number')
plt.title('Impact of Algorithm Type on Relevant Ads')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 0                1                Yes    German Semantic Comparator
# 1                2                Yes    German Semantic Comparator
# 2                3                Yes    German Semantic Comparator
# 3                4                Yes    German Semantic Comparator
# 4                5                Yes    German Semantic Comparator
# 5                6                Yes    German Semantic Comparator
# 6                7                Yes    German Semantic Comparator
# 7                8                Yes    German Semantic Comparator
# 8                9                Yes    German Semantic Comparator
# 9               10                Yes    German Semantic Comparator
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Calculate the mean for the relevant numbers at 25 and 10
aggregated_data_at_25 = data.groupby('Features')['Relevant no. of 25'].mean()
aggregated_data_at_10 = data.groupby('Features')['Relevant no. of 10'].mean()

# Reset the index to make 'Features' a column again
df_25 = aggregated_data_at_25.reset_index(name='Relevant no. of 25')
df_10 = aggregated_data_at_10.reset_index(name='Relevant no. of 10')

# Merge the two DataFrames on the 'Features' column
merged_data = pd.merge(df_25, df_10, on='Features')

# Create a mapping for the feature names to 'feature_1', 'feature_2', ...
feature_mapping = {feature: f'feature_set_{i+1}' for i, feature in enumerate(merged_data['Features'].unique())}

# Apply the mapping to the 'Features' column
merged_data['Features'] = merged_data['Features'].map(feature_mapping)

# Plotting
ax = merged_data.plot(x='Features', y='Relevant no. of 25', kind='bar', color='blue', position=0, width=0.4, label='Relevant no. of 25')
merged_data.plot(x='Features', y='Relevant no. of 10', kind='bar', color='red', position=1, width=0.4, label='Relevant no. of 10', ax=ax)

# Customizing the plot
plt.xlabel('Features')
plt.ylabel('Average Relevant Number')
plt.title('Impact of Features on Relevant Ads')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
import pandas as pd

file_path = "./data/ground_truth.json"

ads = pd.read_json(file_path)

ads_body_text = ads['body_text']

ads_body_text
# Out:
# 0       Sommelier gibt zu: Alle Weine schmecken exakt ...
# 1       Mountainbiken in der Steiermark: ein Fest für ...
# 2       Das Online-Girokonto\nFür alle, die ihre Bankg...
# 3       Der Privatkredit\nEin Kredit, der so spontan i...
# 4       Endlich! Schnellstart ins Programmieren mit Py...
#                               ...
# 1420    Wien - Korfu\n41 €\nJetzt buchen\nWien - Malé\...
# 1421    Wien - Korfu\n€44\nJetzt buchen\nWien -\nVened...
# 1422    -20%\nHAMMER\n€ 68.58\nAlles für deine Tour de...
# 1423    Finde Günstige Flüge\ncheckfelix\nWien - Banja...
# 1424    Fair Fashion\nModerne Designs, elegante Klassi...
# Name: body_text, Length: 1425, dtype: object

# %%
word_counts = ads_body_text.apply(lambda x: len(str(x).split()))

# Calculate the average number of words
average_word_count = word_counts.mean()

# %%
average_word_count
# Out:
# 18.183859649122805

# %%
data = df_without_baseline[(df_without_baseline['query'] == 'schnäppchen flüge') ]
best_experiments = data[(data["Data Preprocessing"] == 'No') &
                       (data["Model Type"] == 'German Semantic Comparator') &
                       (data["Algorithm Type"] == 'Cosine Similarity') ]

# %%
best_experiments
# Out:
#      Experiment no. Data Preprocessing                  Model Type  \
# 100              21                 No  German Semantic Comparator
# 101              22                 No  German Semantic Comparator
# 102              23                 No  German Semantic Comparator
# 103              24                 No  German Semantic Comparator
# 104              25                 No  German Semantic Comparator
#
#         Algorithm Type                                           Features  \
# 100  Cosine Similarity                                          body_text
# 101  Cosine Similarity                  body_text, advertiser domain name
# 102  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 103  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 104  Cosine Similarity  body_text, advertiser domain name, Image Capti...
#
#      Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "./xlsx/experiment_results.xlsx"

# %%
df = pd.read_excel(file_path)

# %%
df_cosine = df[(df['Algorithm Type'] != 'Euclidean Distance') ]

# %%
df_cosine
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 0                 1                Yes    German Semantic Comparator
# 1                 2                Yes    German Semantic Comparator
# 2                 3                Yes    German Semantic Comparator
# 3                 4                Yes    German Semantic Comparator
# 4                 5                Yes    German Semantic Comparator
# ..              ...                ...                           ...
# 113              34                 No  MultiLang Efficient Embedder
# 114              35                 No  MultiLang Efficient Embedder
# 120               1                NaN                      baseline
# 121               2                NaN                      baseline
# 122               3                NaN                      baseline
#
#         Algorithm Type                                           Features  \
# ...

# %%
df_without_baseline = df.iloc[:-3]

# %%
df_without_baseline
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 0                 1                Yes    German Semantic Comparator
# 1                 2                Yes    German Semantic Comparator
# 2                 3                Yes    German Semantic Comparator
# 3                 4                Yes    German Semantic Comparator
# 4                 5                Yes    German Semantic Comparator
# ..              ...                ...                           ...
# 115              36                 No  MultiLang Efficient Embedder
# 116              37                 No  MultiLang Efficient Embedder
# 117              38                 No  MultiLang Efficient Embedder
# 118              39                 No  MultiLang Efficient Embedder
# 119              40                 No  MultiLang Efficient Embedder
#
#          Algorithm Type                                           Features  \
# ...

# %%
def plot_grouped_frame( f, labelrotation=15 ):
    """"""
    # setup the plot with two plots in one row
    fig, (ax1,ax2) = plt.subplots( 1,2 , sharey=True, figsize=(12, 3) )
    # plot Relevant@25 on the left
    f.unstack()["Relevant no. of 25"].plot( kind="bar", ax=ax1, ylabel="Relevant", xlabel="", legend=False)
    # plot Relevant@10 on the right
    f.unstack()["Relevant no. of 10"].plot( kind="bar", ax=ax2, ylabel="Relevant", xlabel="" )
    
    # set the titles for each plot
    ax1.set_title("Relevant@25")
    ax2.set_title("Relevant@10")
    
    # set some properties for each of the plots
    for ax in [ax1,ax2]:
        if labelrotation is not None:
            # rotate x-axis labels
            ax.tick_params(axis='x', labelrotation=labelrotation)
        # set gridlines on y-axis
        ax.yaxis.grid(True, linestyle='--', )
        # put axis into back, so that bars are on top
        ax.set_axisbelow(True)
        # remove the spines (box/frame) for the plot
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['bottom'].set_visible(False)
        ax.spines['left'].set_visible(False)

# %%
def code_feature_set( f ):
    """"""
    if "body_text" == f:
        return "Feature Set 1"
    elif "body_text, advertiser domain name" == f:
        return "Feature Set 2"
    elif "body_text, advertiser domain name, Image Caption" == f:
        return "Feature Set 3"
    elif "body_text, advertiser domain name, Image Caption, keywords" == f:
        return "Feature Set 4"
    elif "body_text, advertiser domain name, Image Caption, keywords, combined_description" == f:
        return "Feature Set 5"
    else:
        return ""

# this translates the features (list per cell) into categorical values
df["Feature Set"] = df_cosine["Features"].apply( code_feature_set )

# %% [markdown]
# # Vergleich der Modelle pro similarity measure

# %%
f = df_without_baseline.groupby( by=["Algorithm Type", "Model Type"] ).agg( { "Relevant no. of 25": "mean", "Relevant no. of 10": "mean" } )

# %%
plot_grouped_frame( f, labelrotation=0 )

# %% [markdown]
# # Vergleich der Modelle pro query (nur Cosine Similarity)

# %%
f = df_cosine.groupby( by=["query", "Model Type"] ).agg( { "Relevant no. of 25": "mean", "Relevant no. of 10": "mean" } )

# %%
plot_grouped_frame( f, labelrotation=15 )

# %% [markdown]
# # Queries gruppiert nach Modell auf x-Achse, Anzahl der relevanten Dokumente auf y-Achse.

# %%
df_cosine
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 0                 1                Yes    German Semantic Comparator
# 1                 2                Yes    German Semantic Comparator
# 2                 3                Yes    German Semantic Comparator
# 3                 4                Yes    German Semantic Comparator
# 4                 5                Yes    German Semantic Comparator
# ..              ...                ...                           ...
# 113              34                 No  MultiLang Efficient Embedder
# 114              35                 No  MultiLang Efficient Embedder
# 120               1                NaN                      baseline
# 121               2                NaN                      baseline
# 122               3                NaN                      baseline
#
#         Algorithm Type                                           Features  \
# ...

# %%
f = df_cosine.groupby( by=["Model Type", "query"] ).agg( { "Relevant no. of 25": "mean", "Relevant no. of 10": "mean" } )

# %%
plot_grouped_frame( f, labelrotation=15 )

# %% [markdown]
# # Impact of Data Processing on Relevant Ads

# %%
df
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 0                 1                Yes    German Semantic Comparator
# 1                 2                Yes    German Semantic Comparator
# 2                 3                Yes    German Semantic Comparator
# 3                 4                Yes    German Semantic Comparator
# 4                 5                Yes    German Semantic Comparator
# ..              ...                ...                           ...
# 118              39                 No  MultiLang Efficient Embedder
# 119              40                 No  MultiLang Efficient Embedder
# 120               1                NaN                      baseline
# 121               2                NaN                      baseline
# 122               3                NaN                      baseline
#
#          Algorithm Type                                           Features  \
# ...

# %%
f = df_cosine.groupby( by=["Data Preprocessing", "Model Type"] ).agg( { "Relevant no. of 25": "mean", "Relevant no. of 10": "mean" } )

# %%
plot_grouped_frame( f, labelrotation=15 )

# %% [markdown]
# # Impact of Features on Relevant Ads

# %%
df["Feature Set"]
# Out:
# 0      Feature Set 1
# 1      Feature Set 2
# 2      Feature Set 3
# 3      Feature Set 4
# 4      Feature Set 5
#            ...
# 118              NaN
# 119              NaN
# 120
# 121
# 122
# Name: Feature Set, Length: 123, dtype: object

# %%
df_cosine = df[(df['Algorithm Type'] != 'Euclidean Distance') ]
df_cosine_without_baseline = df_cosine.iloc[:-3]
df_cosine
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 0                 1                Yes    German Semantic Comparator
# 1                 2                Yes    German Semantic Comparator
# 2                 3                Yes    German Semantic Comparator
# 3                 4                Yes    German Semantic Comparator
# 4                 5                Yes    German Semantic Comparator
# ..              ...                ...                           ...
# 113              34                 No  MultiLang Efficient Embedder
# 114              35                 No  MultiLang Efficient Embedder
# 120               1                NaN                      baseline
# 121               2                NaN                      baseline
# 122               3                NaN                      baseline
#
#         Algorithm Type                                           Features  \
# ...

# %%
df_cosine_without_baseline
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 0                 1                Yes    German Semantic Comparator
# 1                 2                Yes    German Semantic Comparator
# 2                 3                Yes    German Semantic Comparator
# 3                 4                Yes    German Semantic Comparator
# 4                 5                Yes    German Semantic Comparator
# 10               11                Yes  MultiLang Efficient Embedder
# 11               12                Yes  MultiLang Efficient Embedder
# 12               13                Yes  MultiLang Efficient Embedder
# 13               14                Yes  MultiLang Efficient Embedder
# 14               15                Yes  MultiLang Efficient Embedder
# 20               21                 No    German Semantic Comparator
# 21               22                 No    German Semantic Comparator
# 22               23                 No    German Semantic Comparator
# ...

# %%
df_cosine_without_baseline["Features"].value_counts()
# Out:
# Features
# body_text                                                                           12
# body_text, advertiser domain name                                                   12
# body_text, advertiser domain name, Image Caption                                    12
# body_text, advertiser domain name, Image Caption, keywords                          12
# body_text, advertiser domain name, Image Caption, keywords, combined_description    12
# Name: count, dtype: int64

# %%
f = df_cosine_without_baseline.groupby( by=[df["Feature Set"], "Model Type"] ).agg( { "Relevant no. of 25": "mean", "Relevant no. of 10": "mean" } )

# %%
plot_grouped_frame( f, labelrotation=15 )
