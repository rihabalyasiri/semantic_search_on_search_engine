# %%
import pandas as pd

# %%
file_paths = ['./xlsx/wein_kaufen_evaluation_cleaned_full.xlsx', './xlsx/guenstiger_mobilfunktarif_evaluation_cleaned.xlsx', './xlsx/schnaeppchen_fluege_evaluation_cleaned.xlsx']

# %%
def read_excel_file(file_path):
        # Read the Excel file
        return pd.read_excel(file_path)

# %%
frames = [read_excel_file(file_path) for file_path in file_paths]
combined_df = pd.concat(frames, ignore_index=True)

# %%
combined_df
# Out:
#      Experiment no. Data Preprocessing                    Model Type  \
# 0                 1                Yes    German Semantic Comparator
# 1                 2                Yes    German Semantic Comparator
# 2                 3                Yes    German Semantic Comparator
# 3                 4                Yes    German Semantic Comparator
# 4                 5                Yes    German Semantic Comparator
# ..              ...                ...                           ...
# 99               28                 No  MultiLang Efficient Embedder
# 100              29                 No  MultiLang Efficient Embedder
# 101              30                 No  MultiLang Efficient Embedder
# 102              31                 No  MultiLang Efficient Embedder
# 103              32                 No  MultiLang Efficient Embedder
#
#          Algorithm Type                                           Features  \
# 0     Cosine Similarity                                          body_text
# 1     Cosine Similarity                  body_text, advertiser domain name
# 2     Cosine Similarity   body_text, advertiser domain name, Image Caption
# 3     Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 4    Euclidean Distance                                          body_text
# ..                  ...                                                ...
# 99    Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 100  Euclidean Distance                                          body_text
# 101  Euclidean Distance                  body_text, advertiser domain name
# 102  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 103  Euclidean Distance  body_text, advertiser domain name, Image Capti...
#
#      Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 0                             63                  16                   3
# 1                             63                  21                   6
# 2                             63                  20                   7
# 3                             63                  19                   6
# 4                             63                  16                   5
# ..                           ...                 ...                 ...
# 99                           143                   2                   1
# 100                          143                   3                   0
# 101                          143                   1                   0
# 102                          143                   1                   0
# 103                          143                   2                   1
#
#      Precision@10  Recall@10  Precision@25  Recall@25              query
# 0             0.3   0.047619          0.64   0.253968        wein kaufen
# 1             0.6   0.095238          0.84   0.333333        wein kaufen
# 2             0.7   0.111111          0.80   0.317460        wein kaufen
# 3             0.6   0.095238          0.76   0.301587        wein kaufen
# 4             0.5   0.079365          0.64   0.253968        wein kaufen
# ..            ...        ...           ...        ...                ...
# 99            0.1   0.006993          0.08   0.013986  schnäppchen flüge
# 100           0.0   0.000000          0.12   0.020979  schnäppchen flüge
# 101           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 102           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 103           0.1   0.006993          0.08   0.013986  schnäppchen flüge
#
# [104 rows x 13 columns]

# %%
df = combined_df[(combined_df['Data Preprocessing'] == 'Yes') & (combined_df['query'] == 'wein kaufen')]
df_filtered = df.drop(['Total no. of Relevant in db', 'Relevant no. of 25', 'Relevant no. of 10', 'Precision@10', 'Recall@10', 'Precision@25', 'Recall@25', 'query'], axis=1)

# %%
df_filtered
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 0                1                Yes    German Semantic Comparator
# 1                2                Yes    German Semantic Comparator
# 2                3                Yes    German Semantic Comparator
# 3                4                Yes    German Semantic Comparator
# 4                5                Yes    German Semantic Comparator
# 5                6                Yes    German Semantic Comparator
# 6                7                Yes    German Semantic Comparator
# 7                8                Yes    German Semantic Comparator
# 8                9                Yes  MultiLang Efficient Embedder
# 9               10                Yes  MultiLang Efficient Embedder
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# 13              14                Yes  MultiLang Efficient Embedder
# 14              15                Yes  MultiLang Efficient Embedder
# 15              16                Yes  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features
# 0    Cosine Similarity                                          body_text
# 1    Cosine Similarity                  body_text, advertiser domain name
# 2    Cosine Similarity   body_text, advertiser domain name, Image Caption
# 3    Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 4   Euclidean Distance                                          body_text
# 5   Euclidean Distance                  body_text, advertiser domain name
# 6   Euclidean Distance   body_text, advertiser domain name, Image Caption
# 7   Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 8    Cosine Similarity                                          body_text
# 9    Cosine Similarity                  body_text, advertiser domain name
# 10   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 11   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 12  Euclidean Distance                                          body_text
# 13  Euclidean Distance                  body_text, advertiser domain name
# 14  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 15  Euclidean Distance  body_text, advertiser domain name, Image Capti...

# %%
combined_df.describe()
# Out:
#        Experiment no.  Total no. of Relevant in db  Relevant no. of 25  \
# count       96.000000                    96.000000           96.000000
# mean        16.500000                    84.666667           12.552083
# std          9.281561                    41.918886            8.075785
# min          1.000000                    48.000000            0.000000
# 25%          8.750000                    48.000000            3.750000
# 50%         16.500000                    63.000000           13.500000
# 75%         24.250000                   143.000000           20.000000
# max         32.000000                   143.000000           25.000000
#
#        Relevant no. of 10  Precision@10  Recall@10  Precision@25  Recall@25
# count           96.000000     96.000000  96.000000     96.000000  96.000000
# mean             4.979167      0.497917   0.073672      0.502083   0.182190
# std              3.343428      0.334343   0.052933      0.323031   0.124956
# min              0.000000      0.000000   0.000000      0.000000   0.000000
# 25%              2.000000      0.200000   0.041667      0.150000   0.057292
# 50%              5.000000      0.500000   0.069930      0.540000   0.174714
# 75%              8.000000      0.800000   0.104167      0.800000   0.301587
# max             10.000000      1.000000   0.208333      1.000000   0.437500

# %% [markdown]
# # Plotting in bars the whole relevants for the whole Experiments for specific Query

# %%
combined_df[(combined_df['query'] == 'wein kaufen') ].plot(x='Experiment no.', y='Relevant no. of 25', kind='bar')
# Out:
# <Axes: xlabel='Experiment no.'>

# %%
combined_df[(combined_df['query'] == 'schnäppchen flüge') ].plot(x='Experiment no.', y='Relevant no. of 25', kind='bar')
# Out:
# <Axes: xlabel='Experiment no.'>

# %%
combined_df[(combined_df['query'] == 'günstiger mobilfunktarif') ].plot(x='Experiment no.', y='Relevant no. of 25', kind='bar')
# Out:
# <Axes: xlabel='Experiment no.'>

# %% [markdown]
# # Results for Query ( Wein kaufen)

# %% [markdown]
# ### Average of relevant results with data cleaning @10

# %%
data = combined_df[(combined_df['Data Preprocessing'] == 'Yes')  & (combined_df['query'] == 'wein kaufen')]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 0                1                Yes    German Semantic Comparator
# 1                2                Yes    German Semantic Comparator
# 2                3                Yes    German Semantic Comparator
# 3                4                Yes    German Semantic Comparator
# 4                5                Yes    German Semantic Comparator
# 5                6                Yes    German Semantic Comparator
# 6                7                Yes    German Semantic Comparator
# 7                8                Yes    German Semantic Comparator
# 8                9                Yes  MultiLang Efficient Embedder
# 9               10                Yes  MultiLang Efficient Embedder
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# 13              14                Yes  MultiLang Efficient Embedder
# 14              15                Yes  MultiLang Efficient Embedder
# 15              16                Yes  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features  \
# 0    Cosine Similarity                                          body_text
# 1    Cosine Similarity                  body_text, advertiser domain name
# 2    Cosine Similarity   body_text, advertiser domain name, Image Caption
# 3    Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 4   Euclidean Distance                                          body_text
# 5   Euclidean Distance                  body_text, advertiser domain name
# 6   Euclidean Distance   body_text, advertiser domain name, Image Caption
# 7   Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 8    Cosine Similarity                                          body_text
# 9    Cosine Similarity                  body_text, advertiser domain name
# 10   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 11   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 12  Euclidean Distance                                          body_text
# 13  Euclidean Distance                  body_text, advertiser domain name
# 14  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 15  Euclidean Distance  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 0                            63                  16                   3
# 1                            63                  21                   6
# 2                            63                  20                   7
# 3                            63                  19                   6
# 4                            63                  16                   5
# 5                            63                  21                   6
# 6                            63                  19                   7
# 7                            63                  19                   6
# 8                            63                  11                   7
# 9                            63                   6                   2
# 10                           63                   7                   5
# 11                           63                  13                   8
# 12                           63                  10                   7
# 13                           63                   2                   0
# 14                           63                   4                   2
# 15                           63                   9                   5
#
#     Precision@10  Recall@10  Precision@25  Recall@25        query
# 0            0.3   0.047619          0.64   0.253968  wein kaufen
# 1            0.6   0.095238          0.84   0.333333  wein kaufen
# 2            0.7   0.111111          0.80   0.317460  wein kaufen
# 3            0.6   0.095238          0.76   0.301587  wein kaufen
# 4            0.5   0.079365          0.64   0.253968  wein kaufen
# 5            0.6   0.095238          0.84   0.333333  wein kaufen
# 6            0.7   0.111111          0.76   0.301587  wein kaufen
# 7            0.6   0.095238          0.76   0.301587  wein kaufen
# 8            0.7   0.111111          0.44   0.174603  wein kaufen
# 9            0.2   0.031746          0.24   0.095238  wein kaufen
# 10           0.5   0.079365          0.28   0.111111  wein kaufen
# 11           0.8   0.126984          0.52   0.206349  wein kaufen
# 12           0.7   0.111111          0.40   0.158730  wein kaufen
# 13           0.0   0.000000          0.08   0.031746  wein kaufen
# 14           0.2   0.031746          0.16   0.063492  wein kaufen
# 15           0.5   0.079365          0.36   0.142857  wein kaufen

# %%
data['Relevant no. of 10'].mean()
# Out:
# 5.125

# %% [markdown]
# ### Average of relevant results with data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 13.3125

# %% [markdown]
# ### Average of relevant results without data cleaning @10

# %%
data = combined_df[(combined_df['Data Preprocessing'] == 'No') & (combined_df['query'] == 'wein kaufen') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 16              17                 No    German Semantic Comparator
# 17              18                 No    German Semantic Comparator
# 18              19                 No    German Semantic Comparator
# 19              20                 No    German Semantic Comparator
# 20              21                 No    German Semantic Comparator
# 21              22                 No    German Semantic Comparator
# 22              23                 No    German Semantic Comparator
# 23              24                 No    German Semantic Comparator
# 24              25                 No  MultiLang Efficient Embedder
# 25              26                 No  MultiLang Efficient Embedder
# 26              27                 No  MultiLang Efficient Embedder
# 27              28                 No  MultiLang Efficient Embedder
# 28              29                 No  MultiLang Efficient Embedder
# 29              30                 No  MultiLang Efficient Embedder
# 30              31                 No  MultiLang Efficient Embedder
# 31              32                 No  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features  \
# 16   Cosine Similarity                                          body_text
# 17   Cosine Similarity                  body_text, advertiser domain name
# 18   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 19   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 20  Euclidean Distance                                          body_text
# 21  Euclidean Distance                  body_text, advertiser domain name
# 22  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 23  Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 24   Cosine Similarity                                          body_text
# 25   Cosine Similarity                  body_text, advertiser domain name
# 26   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 27   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 28  Euclidean Distance                                          body_text
# 29  Euclidean Distance                  body_text, advertiser domain name
# 30  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 31  Euclidean Distance  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 16                           63                  15                   4
# 17                           63                  20                   6
# 18                           63                  20                   7
# 19                           63                  21                   7
# 20                           63                  15                   4
# 21                           63                  15                   8
# 22                           63                  19                   8
# 23                           63                  20                   7
# 24                           63                  14                   1
# 25                           63                  20                   6
# 26                           63                  24                   9
# 27                           63                  24                  10
# 28                           63                   2                   1
# 29                           63                  14                   3
# 30                           63                  20                   9
# 31                           63                  21                   8
#
#     Precision@10  Recall@10  Precision@25  Recall@25        query
# 16           0.4   0.063492          0.60   0.238095  wein kaufen
# 17           0.6   0.095238          0.80   0.317460  wein kaufen
# 18           0.7   0.111111          0.80   0.317460  wein kaufen
# 19           0.7   0.111111          0.84   0.333333  wein kaufen
# 20           0.4   0.063492          0.60   0.238095  wein kaufen
# 21           0.8   0.126984          0.60   0.238095  wein kaufen
# 22           0.8   0.126984          0.76   0.301587  wein kaufen
# 23           0.7   0.111111          0.80   0.317460  wein kaufen
# 24           0.1   0.015873          0.56   0.222222  wein kaufen
# 25           0.6   0.095238          0.80   0.317460  wein kaufen
# 26           0.9   0.142857          0.96   0.380952  wein kaufen
# 27           1.0   0.158730          0.96   0.380952  wein kaufen
# 28           0.1   0.015873          0.08   0.031746  wein kaufen
# 29           0.3   0.047619          0.56   0.222222  wein kaufen
# 30           0.9   0.142857          0.80   0.317460  wein kaufen
# 31           0.8   0.126984          0.84   0.333333  wein kaufen

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.125

# %% [markdown]
# ### Average of relevant results without data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 17.75

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @10

# %%
data = combined_df[(combined_df['Model Type'] == 'German Semantic Comparator') & (combined_df['query'] == 'wein kaufen') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                  Model Type  \
# 0                1                Yes  German Semantic Comparator
# 1                2                Yes  German Semantic Comparator
# 2                3                Yes  German Semantic Comparator
# 3                4                Yes  German Semantic Comparator
# 4                5                Yes  German Semantic Comparator
# 5                6                Yes  German Semantic Comparator
# 6                7                Yes  German Semantic Comparator
# 7                8                Yes  German Semantic Comparator
# 16              17                 No  German Semantic Comparator
# 17              18                 No  German Semantic Comparator
# 18              19                 No  German Semantic Comparator
# 19              20                 No  German Semantic Comparator
# 20              21                 No  German Semantic Comparator
# 21              22                 No  German Semantic Comparator
# 22              23                 No  German Semantic Comparator
# 23              24                 No  German Semantic Comparator
#
#         Algorithm Type                                           Features  \
# 0    Cosine Similarity                                          body_text
# 1    Cosine Similarity                  body_text, advertiser domain name
# 2    Cosine Similarity   body_text, advertiser domain name, Image Caption
# 3    Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 4   Euclidean Distance                                          body_text
# 5   Euclidean Distance                  body_text, advertiser domain name
# 6   Euclidean Distance   body_text, advertiser domain name, Image Caption
# 7   Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 16   Cosine Similarity                                          body_text
# 17   Cosine Similarity                  body_text, advertiser domain name
# 18   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 19   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 20  Euclidean Distance                                          body_text
# 21  Euclidean Distance                  body_text, advertiser domain name
# 22  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 23  Euclidean Distance  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 0                            63                  16                   3
# 1                            63                  21                   6
# 2                            63                  20                   7
# 3                            63                  19                   6
# 4                            63                  16                   5
# 5                            63                  21                   6
# 6                            63                  19                   7
# 7                            63                  19                   6
# 16                           63                  15                   4
# 17                           63                  20                   6
# 18                           63                  20                   7
# 19                           63                  21                   7
# 20                           63                  15                   4
# 21                           63                  15                   8
# 22                           63                  19                   8
# 23                           63                  20                   7
#
#     Precision@10  Recall@10  Precision@25  Recall@25        query
# 0            0.3   0.047619          0.64   0.253968  wein kaufen
# 1            0.6   0.095238          0.84   0.333333  wein kaufen
# 2            0.7   0.111111          0.80   0.317460  wein kaufen
# 3            0.6   0.095238          0.76   0.301587  wein kaufen
# 4            0.5   0.079365          0.64   0.253968  wein kaufen
# 5            0.6   0.095238          0.84   0.333333  wein kaufen
# 6            0.7   0.111111          0.76   0.301587  wein kaufen
# 7            0.6   0.095238          0.76   0.301587  wein kaufen
# 16           0.4   0.063492          0.60   0.238095  wein kaufen
# 17           0.6   0.095238          0.80   0.317460  wein kaufen
# 18           0.7   0.111111          0.80   0.317460  wein kaufen
# 19           0.7   0.111111          0.84   0.333333  wein kaufen
# 20           0.4   0.063492          0.60   0.238095  wein kaufen
# 21           0.8   0.126984          0.60   0.238095  wein kaufen
# 22           0.8   0.126984          0.76   0.301587  wein kaufen
# 23           0.7   0.111111          0.80   0.317460  wein kaufen

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.0625

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 18.5

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @10

# %%
data = combined_df[(combined_df['Model Type'] == 'MultiLang Efficient Embedder') & (combined_df['query'] == 'wein kaufen') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 8                9                Yes  MultiLang Efficient Embedder
# 9               10                Yes  MultiLang Efficient Embedder
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# 13              14                Yes  MultiLang Efficient Embedder
# 14              15                Yes  MultiLang Efficient Embedder
# 15              16                Yes  MultiLang Efficient Embedder
# 24              25                 No  MultiLang Efficient Embedder
# 25              26                 No  MultiLang Efficient Embedder
# 26              27                 No  MultiLang Efficient Embedder
# 27              28                 No  MultiLang Efficient Embedder
# 28              29                 No  MultiLang Efficient Embedder
# 29              30                 No  MultiLang Efficient Embedder
# 30              31                 No  MultiLang Efficient Embedder
# 31              32                 No  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features  \
# 8    Cosine Similarity                                          body_text
# 9    Cosine Similarity                  body_text, advertiser domain name
# 10   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 11   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 12  Euclidean Distance                                          body_text
# 13  Euclidean Distance                  body_text, advertiser domain name
# 14  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 15  Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 24   Cosine Similarity                                          body_text
# 25   Cosine Similarity                  body_text, advertiser domain name
# 26   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 27   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 28  Euclidean Distance                                          body_text
# 29  Euclidean Distance                  body_text, advertiser domain name
# 30  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 31  Euclidean Distance  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 8                            63                  11                   7
# 9                            63                   6                   2
# 10                           63                   7                   5
# 11                           63                  13                   8
# 12                           63                  10                   7
# 13                           63                   2                   0
# 14                           63                   4                   2
# 15                           63                   9                   5
# 24                           63                  14                   1
# 25                           63                  20                   6
# 26                           63                  24                   9
# 27                           63                  24                  10
# 28                           63                   2                   1
# 29                           63                  14                   3
# 30                           63                  20                   9
# 31                           63                  21                   8
#
#     Precision@10  Recall@10  Precision@25  Recall@25        query
# 8            0.7   0.111111          0.44   0.174603  wein kaufen
# 9            0.2   0.031746          0.24   0.095238  wein kaufen
# 10           0.5   0.079365          0.28   0.111111  wein kaufen
# 11           0.8   0.126984          0.52   0.206349  wein kaufen
# 12           0.7   0.111111          0.40   0.158730  wein kaufen
# 13           0.0   0.000000          0.08   0.031746  wein kaufen
# 14           0.2   0.031746          0.16   0.063492  wein kaufen
# 15           0.5   0.079365          0.36   0.142857  wein kaufen
# 24           0.1   0.015873          0.56   0.222222  wein kaufen
# 25           0.6   0.095238          0.80   0.317460  wein kaufen
# 26           0.9   0.142857          0.96   0.380952  wein kaufen
# 27           1.0   0.158730          0.96   0.380952  wein kaufen
# 28           0.1   0.015873          0.08   0.031746  wein kaufen
# 29           0.3   0.047619          0.56   0.222222  wein kaufen
# 30           0.9   0.142857          0.80   0.317460  wein kaufen
# 31           0.8   0.126984          0.84   0.333333  wein kaufen

# %%
data['Relevant no. of 10'].mean()
# Out:
# 5.1875

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 12.5625

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @10

# %%
data = combined_df[(combined_df['Algorithm Type'] == 'Cosine Similarity') & (combined_df['query'] == 'wein kaufen')]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 0                1                Yes    German Semantic Comparator
# 1                2                Yes    German Semantic Comparator
# 2                3                Yes    German Semantic Comparator
# 3                4                Yes    German Semantic Comparator
# 8                9                Yes  MultiLang Efficient Embedder
# 9               10                Yes  MultiLang Efficient Embedder
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 16              17                 No    German Semantic Comparator
# 17              18                 No    German Semantic Comparator
# 18              19                 No    German Semantic Comparator
# 19              20                 No    German Semantic Comparator
# 24              25                 No  MultiLang Efficient Embedder
# 25              26                 No  MultiLang Efficient Embedder
# 26              27                 No  MultiLang Efficient Embedder
# 27              28                 No  MultiLang Efficient Embedder
#
#        Algorithm Type                                           Features  \
# 0   Cosine Similarity                                          body_text
# 1   Cosine Similarity                  body_text, advertiser domain name
# 2   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 3   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 8   Cosine Similarity                                          body_text
# 9   Cosine Similarity                  body_text, advertiser domain name
# 10  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 11  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 16  Cosine Similarity                                          body_text
# 17  Cosine Similarity                  body_text, advertiser domain name
# 18  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 19  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 24  Cosine Similarity                                          body_text
# 25  Cosine Similarity                  body_text, advertiser domain name
# 26  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 27  Cosine Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 0                            63                  16                   3
# 1                            63                  21                   6
# 2                            63                  20                   7
# 3                            63                  19                   6
# 8                            63                  11                   7
# 9                            63                   6                   2
# 10                           63                   7                   5
# 11                           63                  13                   8
# 16                           63                  15                   4
# 17                           63                  20                   6
# 18                           63                  20                   7
# 19                           63                  21                   7
# 24                           63                  14                   1
# 25                           63                  20                   6
# 26                           63                  24                   9
# 27                           63                  24                  10
#
#     Precision@10  Recall@10  Precision@25  Recall@25        query
# 0            0.3   0.047619          0.64   0.253968  wein kaufen
# 1            0.6   0.095238          0.84   0.333333  wein kaufen
# 2            0.7   0.111111          0.80   0.317460  wein kaufen
# 3            0.6   0.095238          0.76   0.301587  wein kaufen
# 8            0.7   0.111111          0.44   0.174603  wein kaufen
# 9            0.2   0.031746          0.24   0.095238  wein kaufen
# 10           0.5   0.079365          0.28   0.111111  wein kaufen
# 11           0.8   0.126984          0.52   0.206349  wein kaufen
# 16           0.4   0.063492          0.60   0.238095  wein kaufen
# 17           0.6   0.095238          0.80   0.317460  wein kaufen
# 18           0.7   0.111111          0.80   0.317460  wein kaufen
# 19           0.7   0.111111          0.84   0.333333  wein kaufen
# 24           0.1   0.015873          0.56   0.222222  wein kaufen
# 25           0.6   0.095238          0.80   0.317460  wein kaufen
# 26           0.9   0.142857          0.96   0.380952  wein kaufen
# 27           1.0   0.158730          0.96   0.380952  wein kaufen

# %%
data['Relevant no. of 10'].mean()
# Out:
# 5.875

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 16.9375

# %%
data = combined_df[(combined_df['Algorithm Type'] == 'Euclidean Distance') & (combined_df['query'] == 'wein kaufen')]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 4                5                Yes    German Semantic Comparator
# 5                6                Yes    German Semantic Comparator
# 6                7                Yes    German Semantic Comparator
# 7                8                Yes    German Semantic Comparator
# 12              13                Yes  MultiLang Efficient Embedder
# 13              14                Yes  MultiLang Efficient Embedder
# 14              15                Yes  MultiLang Efficient Embedder
# 15              16                Yes  MultiLang Efficient Embedder
# 20              21                 No    German Semantic Comparator
# 21              22                 No    German Semantic Comparator
# 22              23                 No    German Semantic Comparator
# 23              24                 No    German Semantic Comparator
# 28              29                 No  MultiLang Efficient Embedder
# 29              30                 No  MultiLang Efficient Embedder
# 30              31                 No  MultiLang Efficient Embedder
# 31              32                 No  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features  \
# 4   Euclidean Distance                                          body_text
# 5   Euclidean Distance                  body_text, advertiser domain name
# 6   Euclidean Distance   body_text, advertiser domain name, Image Caption
# 7   Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 12  Euclidean Distance                                          body_text
# 13  Euclidean Distance                  body_text, advertiser domain name
# 14  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 15  Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 20  Euclidean Distance                                          body_text
# 21  Euclidean Distance                  body_text, advertiser domain name
# 22  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 23  Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 28  Euclidean Distance                                          body_text
# 29  Euclidean Distance                  body_text, advertiser domain name
# 30  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 31  Euclidean Distance  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 4                            63                  16                   5
# 5                            63                  21                   6
# 6                            63                  19                   7
# 7                            63                  19                   6
# 12                           63                  10                   7
# 13                           63                   2                   0
# 14                           63                   4                   2
# 15                           63                   9                   5
# 20                           63                  15                   4
# 21                           63                  15                   8
# 22                           63                  19                   8
# 23                           63                  20                   7
# 28                           63                   2                   1
# 29                           63                  14                   3
# 30                           63                  20                   9
# 31                           63                  21                   8
#
#     Precision@10  Recall@10  Precision@25  Recall@25        query
# 4            0.5   0.079365          0.64   0.253968  wein kaufen
# 5            0.6   0.095238          0.84   0.333333  wein kaufen
# 6            0.7   0.111111          0.76   0.301587  wein kaufen
# 7            0.6   0.095238          0.76   0.301587  wein kaufen
# 12           0.7   0.111111          0.40   0.158730  wein kaufen
# 13           0.0   0.000000          0.08   0.031746  wein kaufen
# 14           0.2   0.031746          0.16   0.063492  wein kaufen
# 15           0.5   0.079365          0.36   0.142857  wein kaufen
# 20           0.4   0.063492          0.60   0.238095  wein kaufen
# 21           0.8   0.126984          0.60   0.238095  wein kaufen
# 22           0.8   0.126984          0.76   0.301587  wein kaufen
# 23           0.7   0.111111          0.80   0.317460  wein kaufen
# 28           0.1   0.015873          0.08   0.031746  wein kaufen
# 29           0.3   0.047619          0.56   0.222222  wein kaufen
# 30           0.9   0.142857          0.80   0.317460  wein kaufen
# 31           0.8   0.126984          0.84   0.333333  wein kaufen

# %%
data['Relevant no. of 10'].mean()
# Out:
# 5.375

# %%
data['Relevant no. of 25'].mean()
# Out:
# 14.125

# %%
data = combined_df[(combined_df['Algorithm Type'] == 'Cosine Similarity') 
                   & (combined_df['Data Preprocessing'] == 'No') 
                   & (combined_df['Model Type'] == 'German Semantic Comparator') 
                   & (combined_df['query'] == 'wein kaufen')]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                  Model Type  \
# 16              17                 No  German Semantic Comparator
# 17              18                 No  German Semantic Comparator
# 18              19                 No  German Semantic Comparator
# 19              20                 No  German Semantic Comparator
#
#        Algorithm Type                                           Features  \
# 16  Cosine Similarity                                          body_text
# 17  Cosine Similarity                  body_text, advertiser domain name
# 18  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 19  Cosine Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 16                           63                  15                   4
# 17                           63                  20                   6
# 18                           63                  20                   7
# 19                           63                  21                   7
#
#     Precision@10  Recall@10  Precision@25  Recall@25        query
# 16           0.4   0.063492          0.60   0.238095  wein kaufen
# 17           0.6   0.095238          0.80   0.317460  wein kaufen
# 18           0.7   0.111111          0.80   0.317460  wein kaufen
# 19           0.7   0.111111          0.84   0.333333  wein kaufen

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.0

# %%
data['Relevant no. of 25'].mean()
# Out:
# 19.0

# %% [markdown]
# # Results for Query ( schnäppchen Flüge)

# %% [markdown]
# ### Average of relevant results with data cleaning @10

# %%
data = combined_df[(combined_df['Data Cleaning'] == 'Yes') & (combined_df['query'] == 'schnäppchen flüge') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#     Experiment no. Data Cleaning                    Model Type  \
# 53             1.0           Yes    German Semantic Comparator
# 54             2.0           Yes    German Semantic Comparator
# 55             3.0           Yes    German Semantic Comparator
# 56             4.0           Yes    German Semantic Comparator
# 57             5.0           Yes    German Semantic Comparator
# 58             6.0           Yes    German Semantic Comparator
# 59             7.0           Yes    German Semantic Comparator
# 60             8.0           Yes    German Semantic Comparator
# 61             9.0           Yes  MultiLang Efficient Embedder
# 62            10.0           Yes  MultiLang Efficient Embedder
# 63            11.0           Yes  MultiLang Efficient Embedder
# 64            12.0           Yes  MultiLang Efficient Embedder
# 65            13.0           Yes  MultiLang Efficient Embedder
# 66            14.0           Yes  MultiLang Efficient Embedder
# 67            15.0           Yes  MultiLang Efficient Embedder
# 68            16.0           Yes  MultiLang Efficient Embedder
#
#        Algorithm Type                                           Features  \
# 53  Cosine Similarity                                          body_text
# 54  Cosine Similarity                  body_text, advertiser domain name
# 55  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 56  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 57   Faiss Similarity                                          body_text
# 58   Faiss Similarity                  body_text, advertiser domain name
# 59   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 60   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 61  Cosine Similarity                                          body_text
# 62  Cosine Similarity                  body_text, advertiser domain name
# 63  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 64  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 65   Faiss Similarity                                          body_text
# 66   Faiss Similarity                  body_text, advertiser domain name
# 67   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 68   Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 53                        143.0                23.0                 8.0
# 54                        143.0                24.0                10.0
# 55                        143.0                25.0                10.0
# 56                        143.0                20.0                10.0
# 57                        143.0                23.0                 9.0
# 58                        143.0                25.0                10.0
# 59                        143.0                25.0                10.0
# 60                        143.0                21.0                10.0
# 61                        143.0                 1.0                 0.0
# 62                        143.0                 3.0                 0.0
# 63                        143.0                 2.0                 0.0
# 64                        143.0                 2.0                 0.0
# 65                        143.0                 0.0                 0.0
# 66                        143.0                 2.0                 0.0
# 67                        143.0                 0.0                 0.0
# 68                        143.0                 1.0                 0.0
#
#     Precision@10  Recall@10  Precision@25  Recall@25              query
# 53           0.8   0.055944          0.92   0.160839  schnäppchen flüge
# 54           1.0   0.069930          0.96   0.167832  schnäppchen flüge
# 55           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 56           1.0   0.069930          0.80   0.139860  schnäppchen flüge
# 57           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 58           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 59           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 60           1.0   0.069930          0.84   0.146853  schnäppchen flüge
# 61           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 62           0.0   0.000000          0.12   0.020979  schnäppchen flüge
# 63           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 64           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 65           0.0   0.000000          0.00   0.000000  schnäppchen flüge
# 66           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 67           0.0   0.000000          0.00   0.000000  schnäppchen flüge
# 68           0.0   0.000000          0.04   0.006993  schnäppchen flüge

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.8125

# %% [markdown]
# ### Average of relevant results with data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 12.3125

# %% [markdown]
# ### Average of relevant results without data cleaning @10

# %%
data = combined_df[(combined_df['Data Cleaning'] == 'No') & (combined_df['query'] == 'schnäppchen flüge') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#     Experiment no. Data Cleaning                    Model Type  \
# 69            17.0            No    German Semantic Comparator
# 70            18.0            No    German Semantic Comparator
# 71            19.0            No    German Semantic Comparator
# 72            20.0            No    German Semantic Comparator
# 73            21.0            No    German Semantic Comparator
# 74            22.0            No    German Semantic Comparator
# 75            23.0            No    German Semantic Comparator
# 76            24.0            No    German Semantic Comparator
# 77            25.0            No  MultiLang Efficient Embedder
# 78            26.0            No  MultiLang Efficient Embedder
# 79            27.0            No  MultiLang Efficient Embedder
# 80            28.0            No  MultiLang Efficient Embedder
# 81            29.0            No  MultiLang Efficient Embedder
# 82            30.0            No  MultiLang Efficient Embedder
# 83            31.0            No  MultiLang Efficient Embedder
# 84            32.0            No  MultiLang Efficient Embedder
#
#        Algorithm Type                                           Features  \
# 69  Cosine Similarity                                          body_text
# 70  Cosine Similarity                  body_text, advertiser domain name
# 71  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 72  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 73   Faiss Similarity                                          body_text
# 74   Faiss Similarity                  body_text, advertiser domain name
# 75   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 76   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 77  Cosine Similarity                                          body_text
# 78  Cosine Similarity                  body_text, advertiser domain name
# 79  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 80  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 81   Faiss Similarity                                          body_text
# 82   Faiss Similarity                  body_text, advertiser domain name
# 83   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 84   Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 69                        143.0                15.0                 6.0
# 70                        143.0                23.0                 9.0
# 71                        143.0                24.0                 9.0
# 72                        143.0                17.0                 7.0
# 73                        143.0                15.0                 6.0
# 74                        143.0                23.0                 9.0
# 75                        143.0                24.0                10.0
# 76                        143.0                18.0                 7.0
# 77                        143.0                 4.0                 1.0
# 78                        143.0                 2.0                 0.0
# 79                        143.0                 1.0                 1.0
# 80                        143.0                 2.0                 1.0
# 81                        143.0                 3.0                 0.0
# 82                        143.0                 1.0                 0.0
# 83                        143.0                 1.0                 0.0
# 84                        143.0                 2.0                 1.0
#
#     Precision@10  Recall@10  Precision@25  Recall@25              query
# 69           0.6   0.041958          0.60   0.104895  schnäppchen flüge
# 70           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 71           0.9   0.062937          0.96   0.167832  schnäppchen flüge
# 72           0.7   0.048951          0.68   0.118881  schnäppchen flüge
# 73           0.6   0.041958          0.60   0.104895  schnäppchen flüge
# 74           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 75           1.0   0.069930          0.96   0.167832  schnäppchen flüge
# 76           0.7   0.048951          0.72   0.125874  schnäppchen flüge
# 77           0.1   0.006993          0.16   0.027972  schnäppchen flüge
# 78           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 79           0.1   0.006993          0.04   0.006993  schnäppchen flüge
# 80           0.1   0.006993          0.08   0.013986  schnäppchen flüge
# 81           0.0   0.000000          0.12   0.020979  schnäppchen flüge
# 82           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 83           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 84           0.1   0.006993          0.08   0.013986  schnäppchen flüge

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.1875

# %% [markdown]
# ### Average of relevant results without data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 10.9375

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @10

# %%
data = combined_df[(combined_df['Model Type'] == 'German Semantic Comparator') & (combined_df['query'] == 'schnäppchen flüge') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#     Experiment no. Data Cleaning                  Model Type  \
# 53             1.0           Yes  German Semantic Comparator
# 54             2.0           Yes  German Semantic Comparator
# 55             3.0           Yes  German Semantic Comparator
# 56             4.0           Yes  German Semantic Comparator
# 57             5.0           Yes  German Semantic Comparator
# 58             6.0           Yes  German Semantic Comparator
# 59             7.0           Yes  German Semantic Comparator
# 60             8.0           Yes  German Semantic Comparator
# 69            17.0            No  German Semantic Comparator
# 70            18.0            No  German Semantic Comparator
# 71            19.0            No  German Semantic Comparator
# 72            20.0            No  German Semantic Comparator
# 73            21.0            No  German Semantic Comparator
# 74            22.0            No  German Semantic Comparator
# 75            23.0            No  German Semantic Comparator
# 76            24.0            No  German Semantic Comparator
#
#        Algorithm Type                                           Features  \
# 53  Cosine Similarity                                          body_text
# 54  Cosine Similarity                  body_text, advertiser domain name
# 55  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 56  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 57   Faiss Similarity                                          body_text
# 58   Faiss Similarity                  body_text, advertiser domain name
# 59   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 60   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 69  Cosine Similarity                                          body_text
# 70  Cosine Similarity                  body_text, advertiser domain name
# 71  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 72  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 73   Faiss Similarity                                          body_text
# 74   Faiss Similarity                  body_text, advertiser domain name
# 75   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 76   Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 53                        143.0                23.0                 8.0
# 54                        143.0                24.0                10.0
# 55                        143.0                25.0                10.0
# 56                        143.0                20.0                10.0
# 57                        143.0                23.0                 9.0
# 58                        143.0                25.0                10.0
# 59                        143.0                25.0                10.0
# 60                        143.0                21.0                10.0
# 69                        143.0                15.0                 6.0
# 70                        143.0                23.0                 9.0
# 71                        143.0                24.0                 9.0
# 72                        143.0                17.0                 7.0
# 73                        143.0                15.0                 6.0
# 74                        143.0                23.0                 9.0
# 75                        143.0                24.0                10.0
# 76                        143.0                18.0                 7.0
#
#     Precision@10  Recall@10  Precision@25  Recall@25              query
# 53           0.8   0.055944          0.92   0.160839  schnäppchen flüge
# 54           1.0   0.069930          0.96   0.167832  schnäppchen flüge
# 55           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 56           1.0   0.069930          0.80   0.139860  schnäppchen flüge
# 57           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 58           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 59           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 60           1.0   0.069930          0.84   0.146853  schnäppchen flüge
# 69           0.6   0.041958          0.60   0.104895  schnäppchen flüge
# 70           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 71           0.9   0.062937          0.96   0.167832  schnäppchen flüge
# 72           0.7   0.048951          0.68   0.118881  schnäppchen flüge
# 73           0.6   0.041958          0.60   0.104895  schnäppchen flüge
# 74           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 75           1.0   0.069930          0.96   0.167832  schnäppchen flüge
# 76           0.7   0.048951          0.72   0.125874  schnäppchen flüge

# %%
data['Relevant no. of 10'].mean()
# Out:
# 8.75

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 21.5625

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @10

# %%
data = combined_df[(combined_df['Model Type'] == 'MultiLang Efficient Embedder') & (combined_df['query'] == 'schnäppchen flüge') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#     Experiment no. Data Cleaning                    Model Type  \
# 61             9.0           Yes  MultiLang Efficient Embedder
# 62            10.0           Yes  MultiLang Efficient Embedder
# 63            11.0           Yes  MultiLang Efficient Embedder
# 64            12.0           Yes  MultiLang Efficient Embedder
# 65            13.0           Yes  MultiLang Efficient Embedder
# 66            14.0           Yes  MultiLang Efficient Embedder
# 67            15.0           Yes  MultiLang Efficient Embedder
# 68            16.0           Yes  MultiLang Efficient Embedder
# 77            25.0            No  MultiLang Efficient Embedder
# 78            26.0            No  MultiLang Efficient Embedder
# 79            27.0            No  MultiLang Efficient Embedder
# 80            28.0            No  MultiLang Efficient Embedder
# 81            29.0            No  MultiLang Efficient Embedder
# 82            30.0            No  MultiLang Efficient Embedder
# 83            31.0            No  MultiLang Efficient Embedder
# 84            32.0            No  MultiLang Efficient Embedder
#
#        Algorithm Type                                           Features  \
# 61  Cosine Similarity                                          body_text
# 62  Cosine Similarity                  body_text, advertiser domain name
# 63  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 64  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 65   Faiss Similarity                                          body_text
# 66   Faiss Similarity                  body_text, advertiser domain name
# 67   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 68   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 77  Cosine Similarity                                          body_text
# 78  Cosine Similarity                  body_text, advertiser domain name
# 79  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 80  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 81   Faiss Similarity                                          body_text
# 82   Faiss Similarity                  body_text, advertiser domain name
# 83   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 84   Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 61                        143.0                 1.0                 0.0
# 62                        143.0                 3.0                 0.0
# 63                        143.0                 2.0                 0.0
# 64                        143.0                 2.0                 0.0
# 65                        143.0                 0.0                 0.0
# 66                        143.0                 2.0                 0.0
# 67                        143.0                 0.0                 0.0
# 68                        143.0                 1.0                 0.0
# 77                        143.0                 4.0                 1.0
# 78                        143.0                 2.0                 0.0
# 79                        143.0                 1.0                 1.0
# 80                        143.0                 2.0                 1.0
# 81                        143.0                 3.0                 0.0
# 82                        143.0                 1.0                 0.0
# 83                        143.0                 1.0                 0.0
# 84                        143.0                 2.0                 1.0
#
#     Precision@10  Recall@10  Precision@25  Recall@25              query
# 61           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 62           0.0   0.000000          0.12   0.020979  schnäppchen flüge
# 63           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 64           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 65           0.0   0.000000          0.00   0.000000  schnäppchen flüge
# 66           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 67           0.0   0.000000          0.00   0.000000  schnäppchen flüge
# 68           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 77           0.1   0.006993          0.16   0.027972  schnäppchen flüge
# 78           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 79           0.1   0.006993          0.04   0.006993  schnäppchen flüge
# 80           0.1   0.006993          0.08   0.013986  schnäppchen flüge
# 81           0.0   0.000000          0.12   0.020979  schnäppchen flüge
# 82           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 83           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 84           0.1   0.006993          0.08   0.013986  schnäppchen flüge

# %%
data['Relevant no. of 10'].mean()
# Out:
# 0.25

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 1.6875

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @10

# %%
data = combined_df[(combined_df['Algorithm Type'] == 'Cosine Similarity') & (combined_df['query'] == 'schnäppchen flüge') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#     Experiment no. Data Cleaning                    Model Type  \
# 53             1.0           Yes    German Semantic Comparator
# 54             2.0           Yes    German Semantic Comparator
# 55             3.0           Yes    German Semantic Comparator
# 56             4.0           Yes    German Semantic Comparator
# 61             9.0           Yes  MultiLang Efficient Embedder
# 62            10.0           Yes  MultiLang Efficient Embedder
# 63            11.0           Yes  MultiLang Efficient Embedder
# 64            12.0           Yes  MultiLang Efficient Embedder
# 69            17.0            No    German Semantic Comparator
# 70            18.0            No    German Semantic Comparator
# 71            19.0            No    German Semantic Comparator
# 72            20.0            No    German Semantic Comparator
# 77            25.0            No  MultiLang Efficient Embedder
# 78            26.0            No  MultiLang Efficient Embedder
# 79            27.0            No  MultiLang Efficient Embedder
# 80            28.0            No  MultiLang Efficient Embedder
#
#        Algorithm Type                                           Features  \
# 53  Cosine Similarity                                          body_text
# 54  Cosine Similarity                  body_text, advertiser domain name
# 55  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 56  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 61  Cosine Similarity                                          body_text
# 62  Cosine Similarity                  body_text, advertiser domain name
# 63  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 64  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 69  Cosine Similarity                                          body_text
# 70  Cosine Similarity                  body_text, advertiser domain name
# 71  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 72  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 77  Cosine Similarity                                          body_text
# 78  Cosine Similarity                  body_text, advertiser domain name
# 79  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 80  Cosine Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 53                        143.0                23.0                 8.0
# 54                        143.0                24.0                10.0
# 55                        143.0                25.0                10.0
# 56                        143.0                20.0                10.0
# 61                        143.0                 1.0                 0.0
# 62                        143.0                 3.0                 0.0
# 63                        143.0                 2.0                 0.0
# 64                        143.0                 2.0                 0.0
# 69                        143.0                15.0                 6.0
# 70                        143.0                23.0                 9.0
# 71                        143.0                24.0                 9.0
# 72                        143.0                17.0                 7.0
# 77                        143.0                 4.0                 1.0
# 78                        143.0                 2.0                 0.0
# 79                        143.0                 1.0                 1.0
# 80                        143.0                 2.0                 1.0
#
#     Precision@10  Recall@10  Precision@25  Recall@25              query
# 53           0.8   0.055944          0.92   0.160839  schnäppchen flüge
# 54           1.0   0.069930          0.96   0.167832  schnäppchen flüge
# 55           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 56           1.0   0.069930          0.80   0.139860  schnäppchen flüge
# 61           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 62           0.0   0.000000          0.12   0.020979  schnäppchen flüge
# 63           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 64           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 69           0.6   0.041958          0.60   0.104895  schnäppchen flüge
# 70           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 71           0.9   0.062937          0.96   0.167832  schnäppchen flüge
# 72           0.7   0.048951          0.68   0.118881  schnäppchen flüge
# 77           0.1   0.006993          0.16   0.027972  schnäppchen flüge
# 78           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 79           0.1   0.006993          0.04   0.006993  schnäppchen flüge
# 80           0.1   0.006993          0.08   0.013986  schnäppchen flüge

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.5

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 11.75

# %% [markdown]
# ### Average of relevant results with Faiss Similarity@10

# %%
data = combined_df[(combined_df['Algorithm Type'] == 'Faiss Similarity') & (combined_df['query'] == 'schnäppchen flüge') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#     Experiment no. Data Cleaning                    Model Type  \
# 57             5.0           Yes    German Semantic Comparator
# 58             6.0           Yes    German Semantic Comparator
# 59             7.0           Yes    German Semantic Comparator
# 60             8.0           Yes    German Semantic Comparator
# 65            13.0           Yes  MultiLang Efficient Embedder
# 66            14.0           Yes  MultiLang Efficient Embedder
# 67            15.0           Yes  MultiLang Efficient Embedder
# 68            16.0           Yes  MultiLang Efficient Embedder
# 73            21.0            No    German Semantic Comparator
# 74            22.0            No    German Semantic Comparator
# 75            23.0            No    German Semantic Comparator
# 76            24.0            No    German Semantic Comparator
# 81            29.0            No  MultiLang Efficient Embedder
# 82            30.0            No  MultiLang Efficient Embedder
# 83            31.0            No  MultiLang Efficient Embedder
# 84            32.0            No  MultiLang Efficient Embedder
#
#       Algorithm Type                                           Features  \
# 57  Faiss Similarity                                          body_text
# 58  Faiss Similarity                  body_text, advertiser domain name
# 59  Faiss Similarity   body_text, advertiser domain name, Image Caption
# 60  Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 65  Faiss Similarity                                          body_text
# 66  Faiss Similarity                  body_text, advertiser domain name
# 67  Faiss Similarity   body_text, advertiser domain name, Image Caption
# 68  Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 73  Faiss Similarity                                          body_text
# 74  Faiss Similarity                  body_text, advertiser domain name
# 75  Faiss Similarity   body_text, advertiser domain name, Image Caption
# 76  Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 81  Faiss Similarity                                          body_text
# 82  Faiss Similarity                  body_text, advertiser domain name
# 83  Faiss Similarity   body_text, advertiser domain name, Image Caption
# 84  Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 57                        143.0                23.0                 9.0
# 58                        143.0                25.0                10.0
# 59                        143.0                25.0                10.0
# 60                        143.0                21.0                10.0
# 65                        143.0                 0.0                 0.0
# 66                        143.0                 2.0                 0.0
# 67                        143.0                 0.0                 0.0
# 68                        143.0                 1.0                 0.0
# 73                        143.0                15.0                 6.0
# 74                        143.0                23.0                 9.0
# 75                        143.0                24.0                10.0
# 76                        143.0                18.0                 7.0
# 81                        143.0                 3.0                 0.0
# 82                        143.0                 1.0                 0.0
# 83                        143.0                 1.0                 0.0
# 84                        143.0                 2.0                 1.0
#
#     Precision@10  Recall@10  Precision@25  Recall@25              query
# 57           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 58           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 59           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 60           1.0   0.069930          0.84   0.146853  schnäppchen flüge
# 65           0.0   0.000000          0.00   0.000000  schnäppchen flüge
# 66           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 67           0.0   0.000000          0.00   0.000000  schnäppchen flüge
# 68           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 73           0.6   0.041958          0.60   0.104895  schnäppchen flüge
# 74           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 75           1.0   0.069930          0.96   0.167832  schnäppchen flüge
# 76           0.7   0.048951          0.72   0.125874  schnäppchen flüge
# 81           0.0   0.000000          0.12   0.020979  schnäppchen flüge
# 82           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 83           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 84           0.1   0.006993          0.08   0.013986  schnäppchen flüge

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.5

# %% [markdown]
# ### Average of relevant results with Faiss Similarity @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 11.5

# %% [markdown]
# # Results for Query ( günstiger Mobilfunktarif)

# %% [markdown]
# ### Average of relevant results with data cleaning @10

# %%
data = combined_df[(combined_df['Data Cleaning'] == 'Yes') & (combined_df['query'] == 'günstiger mobilfunktarif') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#      Experiment no. Data Cleaning                    Model Type  \
# 101             1.0           Yes    German Semantic Comparator
# 102             2.0           Yes    German Semantic Comparator
# 103             3.0           Yes    German Semantic Comparator
# 104             4.0           Yes    German Semantic Comparator
# 105             5.0           Yes    German Semantic Comparator
# 106             6.0           Yes    German Semantic Comparator
# 107             7.0           Yes    German Semantic Comparator
# 108             8.0           Yes    German Semantic Comparator
# 109             9.0           Yes  MultiLang Efficient Embedder
# 110            10.0           Yes  MultiLang Efficient Embedder
# 111            11.0           Yes  MultiLang Efficient Embedder
# 112            12.0           Yes  MultiLang Efficient Embedder
# 113            13.0           Yes  MultiLang Efficient Embedder
# 114            14.0           Yes  MultiLang Efficient Embedder
# 115            15.0           Yes  MultiLang Efficient Embedder
# 116            16.0           Yes  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features  \
# 101  Cosine Similarity                                          body_text
# 102  Cosine Similarity                  body_text, advertiser domain name
# 103  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 104  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 105   Faiss Similarity                                          body_text
# 106   Faiss Similarity                  body_text, advertiser domain name
# 107   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 108   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 109  Cosine Similarity                                          body_text
# 110  Cosine Similarity                  body_text, advertiser domain name
# 111  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 112  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 113   Faiss Similarity                                          body_text
# 114   Faiss Similarity                  body_text, advertiser domain name
# 115   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 116   Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#      Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 101                         48.0                12.0                 4.0
# 102                         48.0                 9.0                 5.0
# 103                         48.0                10.0                 3.0
# 104                         48.0                 7.0                 4.0
# 105                         48.0                12.0                 4.0
# 106                         48.0                 9.0                 5.0
# 107                         48.0                 9.0                 4.0
# 108                         48.0                 7.0                 4.0
# 109                         48.0                 3.0                 2.0
# 110                         48.0                 2.0                 2.0
# 111                         48.0                 2.0                 2.0
# 112                         48.0                 2.0                 2.0
# 113                         48.0                 4.0                 2.0
# 114                         48.0                 2.0                 2.0
# 115                         48.0                 2.0                 2.0
# 116                         48.0                 2.0                 2.0
#
#      Precision@10  Recall@10  Precision@25  Recall@25  \
# 101           0.4   0.083333          0.48   0.250000
# 102           0.5   0.104167          0.36   0.187500
# 103           0.3   0.062500          0.40   0.208333
# 104           0.4   0.083333          0.28   0.145833
# 105           0.4   0.083333          0.48   0.250000
# 106           0.5   0.104167          0.36   0.187500
# 107           0.4   0.083333          0.36   0.187500
# 108           0.4   0.083333          0.28   0.145833
# 109           0.2   0.041667          0.12   0.062500
# 110           0.2   0.041667          0.08   0.041667
# 111           0.2   0.041667          0.08   0.041667
# 112           0.2   0.041667          0.08   0.041667
# 113           0.2   0.041667          0.16   0.083333
# 114           0.2   0.041667          0.08   0.041667
# 115           0.2   0.041667          0.08   0.041667
# 116           0.2   0.041667          0.08   0.041667
#
#                         query
# 101  günstiger mobilfunktarif
# 102  günstiger mobilfunktarif
# 103  günstiger mobilfunktarif
# 104  günstiger mobilfunktarif
# 105  günstiger mobilfunktarif
# 106  günstiger mobilfunktarif
# 107  günstiger mobilfunktarif
# 108  günstiger mobilfunktarif
# 109  günstiger mobilfunktarif
# 110  günstiger mobilfunktarif
# 111  günstiger mobilfunktarif
# 112  günstiger mobilfunktarif
# 113  günstiger mobilfunktarif
# 114  günstiger mobilfunktarif
# 115  günstiger mobilfunktarif
# 116  günstiger mobilfunktarif

# %%
data['Relevant no. of 10'].mean()
# Out:
# 3.0625

# %% [markdown]
# ### Average of relevant results with data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 5.875

# %% [markdown]
# ### Average of relevant results without data cleaning @10

# %%
data = combined_df[(combined_df['Data Cleaning'] == 'No') & (combined_df['query'] == 'günstiger mobilfunktarif') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#      Experiment no. Data Cleaning                    Model Type  \
# 117            17.0            No    German Semantic Comparator
# 118            18.0            No    German Semantic Comparator
# 119            19.0            No    German Semantic Comparator
# 120            20.0            No    German Semantic Comparator
# 121            21.0            No    German Semantic Comparator
# 122            22.0            No    German Semantic Comparator
# 123            23.0            No    German Semantic Comparator
# 124            24.0            No    German Semantic Comparator
# 125            25.0            No  MultiLang Efficient Embedder
# 126            26.0            No  MultiLang Efficient Embedder
# 127            27.0            No  MultiLang Efficient Embedder
# 128            28.0            No  MultiLang Efficient Embedder
# 129            29.0            No  MultiLang Efficient Embedder
# 130            30.0            No  MultiLang Efficient Embedder
# 131            31.0            No  MultiLang Efficient Embedder
# 132            32.0            No  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features  \
# 117  Cosine Similarity                                          body_text
# 118  Cosine Similarity                  body_text, advertiser domain name
# 119  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 120  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 121   Faiss Similarity                                          body_text
# 122   Faiss Similarity                  body_text, advertiser domain name
# 123   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 124   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 125  Cosine Similarity                                          body_text
# 126  Cosine Similarity                  body_text, advertiser domain name
# 127  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 128  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 129   Faiss Similarity                                          body_text
# 130   Faiss Similarity                  body_text, advertiser domain name
# 131   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 132   Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#      Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 117                         48.0                18.0                 8.0
# 118                         48.0                18.0                10.0
# 119                         48.0                20.0                10.0
# 120                         48.0                18.0                 9.0
# 121                         48.0                19.0                 9.0
# 122                         48.0                19.0                 9.0
# 123                         48.0                21.0                 9.0
# 124                         48.0                18.0                 8.0
# 125                         48.0                12.0                 3.0
# 126                         48.0                12.0                 4.0
# 127                         48.0                16.0                 6.0
# 128                         48.0                11.0                 5.0
# 129                         48.0                10.0                 3.0
# 130                         48.0                11.0                 5.0
# 131                         48.0                12.0                 4.0
# 132                         48.0                 7.0                 3.0
#
#      Precision@10  Recall@10  Precision@25  Recall@25  \
# 117           0.8   0.166667          0.72   0.375000
# 118           1.0   0.208333          0.72   0.375000
# 119           1.0   0.208333          0.80   0.416667
# 120           0.9   0.187500          0.72   0.375000
# 121           0.9   0.187500          0.76   0.395833
# 122           0.9   0.187500          0.76   0.395833
# 123           0.9   0.187500          0.84   0.437500
# 124           0.8   0.166667          0.72   0.375000
# 125           0.3   0.062500          0.48   0.250000
# 126           0.4   0.083333          0.48   0.250000
# 127           0.6   0.125000          0.64   0.333333
# 128           0.5   0.104167          0.44   0.229167
# 129           0.3   0.062500          0.40   0.208333
# 130           0.5   0.104167          0.44   0.229167
# 131           0.4   0.083333          0.48   0.250000
# 132           0.3   0.062500          0.28   0.145833
#
#                         query
# 117  günstiger mobilfunktarif
# 118  günstiger mobilfunktarif
# 119  günstiger mobilfunktarif
# 120  günstiger mobilfunktarif
# 121  günstiger mobilfunktarif
# 122  günstiger mobilfunktarif
# 123  günstiger mobilfunktarif
# 124  günstiger mobilfunktarif
# 125  günstiger mobilfunktarif
# 126  günstiger mobilfunktarif
# 127  günstiger mobilfunktarif
# 128  günstiger mobilfunktarif
# 129  günstiger mobilfunktarif
# 130  günstiger mobilfunktarif
# 131  günstiger mobilfunktarif
# 132  günstiger mobilfunktarif

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.5625

# %% [markdown]
# ### Average of relevant results without data cleaning @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 15.125

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @10

# %%
data = combined_df[(combined_df['Model Type'] == 'German Semantic Comparator') & (combined_df['query'] == 'günstiger mobilfunktarif') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#      Experiment no. Data Cleaning                  Model Type  \
# 101             1.0           Yes  German Semantic Comparator
# 102             2.0           Yes  German Semantic Comparator
# 103             3.0           Yes  German Semantic Comparator
# 104             4.0           Yes  German Semantic Comparator
# 105             5.0           Yes  German Semantic Comparator
# 106             6.0           Yes  German Semantic Comparator
# 107             7.0           Yes  German Semantic Comparator
# 108             8.0           Yes  German Semantic Comparator
# 117            17.0            No  German Semantic Comparator
# 118            18.0            No  German Semantic Comparator
# 119            19.0            No  German Semantic Comparator
# 120            20.0            No  German Semantic Comparator
# 121            21.0            No  German Semantic Comparator
# 122            22.0            No  German Semantic Comparator
# 123            23.0            No  German Semantic Comparator
# 124            24.0            No  German Semantic Comparator
#
#         Algorithm Type                                           Features  \
# 101  Cosine Similarity                                          body_text
# 102  Cosine Similarity                  body_text, advertiser domain name
# 103  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 104  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 105   Faiss Similarity                                          body_text
# 106   Faiss Similarity                  body_text, advertiser domain name
# 107   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 108   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 117  Cosine Similarity                                          body_text
# 118  Cosine Similarity                  body_text, advertiser domain name
# 119  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 120  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 121   Faiss Similarity                                          body_text
# 122   Faiss Similarity                  body_text, advertiser domain name
# 123   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 124   Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#      Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 101                         48.0                12.0                 4.0
# 102                         48.0                 9.0                 5.0
# 103                         48.0                10.0                 3.0
# 104                         48.0                 7.0                 4.0
# 105                         48.0                12.0                 4.0
# 106                         48.0                 9.0                 5.0
# 107                         48.0                 9.0                 4.0
# 108                         48.0                 7.0                 4.0
# 117                         48.0                18.0                 8.0
# 118                         48.0                18.0                10.0
# 119                         48.0                20.0                10.0
# 120                         48.0                18.0                 9.0
# 121                         48.0                19.0                 9.0
# 122                         48.0                19.0                 9.0
# 123                         48.0                21.0                 9.0
# 124                         48.0                18.0                 8.0
#
#      Precision@10  Recall@10  Precision@25  Recall@25  \
# 101           0.4   0.083333          0.48   0.250000
# 102           0.5   0.104167          0.36   0.187500
# 103           0.3   0.062500          0.40   0.208333
# 104           0.4   0.083333          0.28   0.145833
# 105           0.4   0.083333          0.48   0.250000
# 106           0.5   0.104167          0.36   0.187500
# 107           0.4   0.083333          0.36   0.187500
# 108           0.4   0.083333          0.28   0.145833
# 117           0.8   0.166667          0.72   0.375000
# 118           1.0   0.208333          0.72   0.375000
# 119           1.0   0.208333          0.80   0.416667
# 120           0.9   0.187500          0.72   0.375000
# 121           0.9   0.187500          0.76   0.395833
# 122           0.9   0.187500          0.76   0.395833
# 123           0.9   0.187500          0.84   0.437500
# 124           0.8   0.166667          0.72   0.375000
#
#                         query
# 101  günstiger mobilfunktarif
# 102  günstiger mobilfunktarif
# 103  günstiger mobilfunktarif
# 104  günstiger mobilfunktarif
# 105  günstiger mobilfunktarif
# 106  günstiger mobilfunktarif
# 107  günstiger mobilfunktarif
# 108  günstiger mobilfunktarif
# 117  günstiger mobilfunktarif
# 118  günstiger mobilfunktarif
# 119  günstiger mobilfunktarif
# 120  günstiger mobilfunktarif
# 121  günstiger mobilfunktarif
# 122  günstiger mobilfunktarif
# 123  günstiger mobilfunktarif
# 124  günstiger mobilfunktarif

# %%
data['Relevant no. of 10'].mean()
# Out:
# 6.5625

# %% [markdown]
# ### Average of relevant results with German Semantic Comparator @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 14.125

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @10

# %%
data = combined_df[(combined_df['Model Type'] == 'MultiLang Efficient Embedder') & (combined_df['query'] == 'günstiger mobilfunktarif') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#      Experiment no. Data Cleaning                    Model Type  \
# 109             9.0           Yes  MultiLang Efficient Embedder
# 110            10.0           Yes  MultiLang Efficient Embedder
# 111            11.0           Yes  MultiLang Efficient Embedder
# 112            12.0           Yes  MultiLang Efficient Embedder
# 113            13.0           Yes  MultiLang Efficient Embedder
# 114            14.0           Yes  MultiLang Efficient Embedder
# 115            15.0           Yes  MultiLang Efficient Embedder
# 116            16.0           Yes  MultiLang Efficient Embedder
# 125            25.0            No  MultiLang Efficient Embedder
# 126            26.0            No  MultiLang Efficient Embedder
# 127            27.0            No  MultiLang Efficient Embedder
# 128            28.0            No  MultiLang Efficient Embedder
# 129            29.0            No  MultiLang Efficient Embedder
# 130            30.0            No  MultiLang Efficient Embedder
# 131            31.0            No  MultiLang Efficient Embedder
# 132            32.0            No  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features  \
# 109  Cosine Similarity                                          body_text
# 110  Cosine Similarity                  body_text, advertiser domain name
# 111  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 112  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 113   Faiss Similarity                                          body_text
# 114   Faiss Similarity                  body_text, advertiser domain name
# 115   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 116   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 125  Cosine Similarity                                          body_text
# 126  Cosine Similarity                  body_text, advertiser domain name
# 127  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 128  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 129   Faiss Similarity                                          body_text
# 130   Faiss Similarity                  body_text, advertiser domain name
# 131   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 132   Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#      Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 109                         48.0                 3.0                 2.0
# 110                         48.0                 2.0                 2.0
# 111                         48.0                 2.0                 2.0
# 112                         48.0                 2.0                 2.0
# 113                         48.0                 4.0                 2.0
# 114                         48.0                 2.0                 2.0
# 115                         48.0                 2.0                 2.0
# 116                         48.0                 2.0                 2.0
# 125                         48.0                12.0                 3.0
# 126                         48.0                12.0                 4.0
# 127                         48.0                16.0                 6.0
# 128                         48.0                11.0                 5.0
# 129                         48.0                10.0                 3.0
# 130                         48.0                11.0                 5.0
# 131                         48.0                12.0                 4.0
# 132                         48.0                 7.0                 3.0
#
#      Precision@10  Recall@10  Precision@25  Recall@25  \
# 109           0.2   0.041667          0.12   0.062500
# 110           0.2   0.041667          0.08   0.041667
# 111           0.2   0.041667          0.08   0.041667
# 112           0.2   0.041667          0.08   0.041667
# 113           0.2   0.041667          0.16   0.083333
# 114           0.2   0.041667          0.08   0.041667
# 115           0.2   0.041667          0.08   0.041667
# 116           0.2   0.041667          0.08   0.041667
# 125           0.3   0.062500          0.48   0.250000
# 126           0.4   0.083333          0.48   0.250000
# 127           0.6   0.125000          0.64   0.333333
# 128           0.5   0.104167          0.44   0.229167
# 129           0.3   0.062500          0.40   0.208333
# 130           0.5   0.104167          0.44   0.229167
# 131           0.4   0.083333          0.48   0.250000
# 132           0.3   0.062500          0.28   0.145833
#
#                         query
# 109  günstiger mobilfunktarif
# 110  günstiger mobilfunktarif
# 111  günstiger mobilfunktarif
# 112  günstiger mobilfunktarif
# 113  günstiger mobilfunktarif
# 114  günstiger mobilfunktarif
# 115  günstiger mobilfunktarif
# 116  günstiger mobilfunktarif
# 125  günstiger mobilfunktarif
# 126  günstiger mobilfunktarif
# 127  günstiger mobilfunktarif
# 128  günstiger mobilfunktarif
# 129  günstiger mobilfunktarif
# 130  günstiger mobilfunktarif
# 131  günstiger mobilfunktarif
# 132  günstiger mobilfunktarif

# %%
data['Relevant no. of 10'].mean()
# Out:
# 3.0625

# %% [markdown]
# ### Average of relevant results with MultiLang Efficient Embedder @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 6.875

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @10

# %%
data = combined_df[(combined_df['Algorithm Type'] == 'Cosine Similarity') & (combined_df['query'] == 'günstiger mobilfunktarif') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#      Experiment no. Data Cleaning                    Model Type  \
# 101             1.0           Yes    German Semantic Comparator
# 102             2.0           Yes    German Semantic Comparator
# 103             3.0           Yes    German Semantic Comparator
# 104             4.0           Yes    German Semantic Comparator
# 109             9.0           Yes  MultiLang Efficient Embedder
# 110            10.0           Yes  MultiLang Efficient Embedder
# 111            11.0           Yes  MultiLang Efficient Embedder
# 112            12.0           Yes  MultiLang Efficient Embedder
# 117            17.0            No    German Semantic Comparator
# 118            18.0            No    German Semantic Comparator
# 119            19.0            No    German Semantic Comparator
# 120            20.0            No    German Semantic Comparator
# 125            25.0            No  MultiLang Efficient Embedder
# 126            26.0            No  MultiLang Efficient Embedder
# 127            27.0            No  MultiLang Efficient Embedder
# 128            28.0            No  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features  \
# 101  Cosine Similarity                                          body_text
# 102  Cosine Similarity                  body_text, advertiser domain name
# 103  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 104  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 109  Cosine Similarity                                          body_text
# 110  Cosine Similarity                  body_text, advertiser domain name
# 111  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 112  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 117  Cosine Similarity                                          body_text
# 118  Cosine Similarity                  body_text, advertiser domain name
# 119  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 120  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 125  Cosine Similarity                                          body_text
# 126  Cosine Similarity                  body_text, advertiser domain name
# 127  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 128  Cosine Similarity  body_text, advertiser domain name, Image Capti...
#
#      Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 101                         48.0                12.0                 4.0
# 102                         48.0                 9.0                 5.0
# 103                         48.0                10.0                 3.0
# 104                         48.0                 7.0                 4.0
# 109                         48.0                 3.0                 2.0
# 110                         48.0                 2.0                 2.0
# 111                         48.0                 2.0                 2.0
# 112                         48.0                 2.0                 2.0
# 117                         48.0                18.0                 8.0
# 118                         48.0                18.0                10.0
# 119                         48.0                20.0                10.0
# 120                         48.0                18.0                 9.0
# 125                         48.0                12.0                 3.0
# 126                         48.0                12.0                 4.0
# 127                         48.0                16.0                 6.0
# 128                         48.0                11.0                 5.0
#
#      Precision@10  Recall@10  Precision@25  Recall@25  \
# 101           0.4   0.083333          0.48   0.250000
# 102           0.5   0.104167          0.36   0.187500
# 103           0.3   0.062500          0.40   0.208333
# 104           0.4   0.083333          0.28   0.145833
# 109           0.2   0.041667          0.12   0.062500
# 110           0.2   0.041667          0.08   0.041667
# 111           0.2   0.041667          0.08   0.041667
# 112           0.2   0.041667          0.08   0.041667
# 117           0.8   0.166667          0.72   0.375000
# 118           1.0   0.208333          0.72   0.375000
# 119           1.0   0.208333          0.80   0.416667
# 120           0.9   0.187500          0.72   0.375000
# 125           0.3   0.062500          0.48   0.250000
# 126           0.4   0.083333          0.48   0.250000
# 127           0.6   0.125000          0.64   0.333333
# 128           0.5   0.104167          0.44   0.229167
#
#                         query
# 101  günstiger mobilfunktarif
# 102  günstiger mobilfunktarif
# 103  günstiger mobilfunktarif
# 104  günstiger mobilfunktarif
# 109  günstiger mobilfunktarif
# 110  günstiger mobilfunktarif
# 111  günstiger mobilfunktarif
# 112  günstiger mobilfunktarif
# 117  günstiger mobilfunktarif
# 118  günstiger mobilfunktarif
# 119  günstiger mobilfunktarif
# 120  günstiger mobilfunktarif
# 125  günstiger mobilfunktarif
# 126  günstiger mobilfunktarif
# 127  günstiger mobilfunktarif
# 128  günstiger mobilfunktarif

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.9375

# %% [markdown]
# ### Average of relevant results with Cosine Similarity @25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 10.75

# %% [markdown]
# ### Average of relevant results with Faiss Similarity@10

# %%
data = combined_df[(combined_df['Algorithm Type'] == 'Faiss Similarity') & (combined_df['query'] == 'günstiger mobilfunktarif') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#      Experiment no. Data Cleaning                    Model Type  \
# 105             5.0           Yes    German Semantic Comparator
# 106             6.0           Yes    German Semantic Comparator
# 107             7.0           Yes    German Semantic Comparator
# 108             8.0           Yes    German Semantic Comparator
# 113            13.0           Yes  MultiLang Efficient Embedder
# 114            14.0           Yes  MultiLang Efficient Embedder
# 115            15.0           Yes  MultiLang Efficient Embedder
# 116            16.0           Yes  MultiLang Efficient Embedder
# 121            21.0            No    German Semantic Comparator
# 122            22.0            No    German Semantic Comparator
# 123            23.0            No    German Semantic Comparator
# 124            24.0            No    German Semantic Comparator
# 129            29.0            No  MultiLang Efficient Embedder
# 130            30.0            No  MultiLang Efficient Embedder
# 131            31.0            No  MultiLang Efficient Embedder
# 132            32.0            No  MultiLang Efficient Embedder
#
#        Algorithm Type                                           Features  \
# 105  Faiss Similarity                                          body_text
# 106  Faiss Similarity                  body_text, advertiser domain name
# 107  Faiss Similarity   body_text, advertiser domain name, Image Caption
# 108  Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 113  Faiss Similarity                                          body_text
# 114  Faiss Similarity                  body_text, advertiser domain name
# 115  Faiss Similarity   body_text, advertiser domain name, Image Caption
# 116  Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 121  Faiss Similarity                                          body_text
# 122  Faiss Similarity                  body_text, advertiser domain name
# 123  Faiss Similarity   body_text, advertiser domain name, Image Caption
# 124  Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 129  Faiss Similarity                                          body_text
# 130  Faiss Similarity                  body_text, advertiser domain name
# 131  Faiss Similarity   body_text, advertiser domain name, Image Caption
# 132  Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#      Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 105                         48.0                12.0                 4.0
# 106                         48.0                 9.0                 5.0
# 107                         48.0                 9.0                 4.0
# 108                         48.0                 7.0                 4.0
# 113                         48.0                 4.0                 2.0
# 114                         48.0                 2.0                 2.0
# 115                         48.0                 2.0                 2.0
# 116                         48.0                 2.0                 2.0
# 121                         48.0                19.0                 9.0
# 122                         48.0                19.0                 9.0
# 123                         48.0                21.0                 9.0
# 124                         48.0                18.0                 8.0
# 129                         48.0                10.0                 3.0
# 130                         48.0                11.0                 5.0
# 131                         48.0                12.0                 4.0
# 132                         48.0                 7.0                 3.0
#
#      Precision@10  Recall@10  Precision@25  Recall@25  \
# 105           0.4   0.083333          0.48   0.250000
# 106           0.5   0.104167          0.36   0.187500
# 107           0.4   0.083333          0.36   0.187500
# 108           0.4   0.083333          0.28   0.145833
# 113           0.2   0.041667          0.16   0.083333
# 114           0.2   0.041667          0.08   0.041667
# 115           0.2   0.041667          0.08   0.041667
# 116           0.2   0.041667          0.08   0.041667
# 121           0.9   0.187500          0.76   0.395833
# 122           0.9   0.187500          0.76   0.395833
# 123           0.9   0.187500          0.84   0.437500
# 124           0.8   0.166667          0.72   0.375000
# 129           0.3   0.062500          0.40   0.208333
# 130           0.5   0.104167          0.44   0.229167
# 131           0.4   0.083333          0.48   0.250000
# 132           0.3   0.062500          0.28   0.145833
#
#                         query
# 105  günstiger mobilfunktarif
# 106  günstiger mobilfunktarif
# 107  günstiger mobilfunktarif
# 108  günstiger mobilfunktarif
# 113  günstiger mobilfunktarif
# 114  günstiger mobilfunktarif
# 115  günstiger mobilfunktarif
# 116  günstiger mobilfunktarif
# 121  günstiger mobilfunktarif
# 122  günstiger mobilfunktarif
# 123  günstiger mobilfunktarif
# 124  günstiger mobilfunktarif
# 129  günstiger mobilfunktarif
# 130  günstiger mobilfunktarif
# 131  günstiger mobilfunktarif
# 132  günstiger mobilfunktarif

# %%
data['Relevant no. of 10'].mean()
# Out:
# 4.6875

# %% [markdown]
# ### Average of relevant results with Faiss Similarity@25

# %%
data['Relevant no. of 25'].mean()
# Out:
# 10.25

# %% [markdown]
# # Precision-Recall-Curve Plot

# %%
data = combined_df[(combined_df['query'] == 'schnäppchen flüge') 
            & (combined_df['Model Type'] != 'DestilBERT')]

# %%
data
# Out:
#     Experiment no. Data Cleaning                    Model Type  \
# 53             1.0           Yes    German Semantic Comparator
# 54             2.0           Yes    German Semantic Comparator
# 55             3.0           Yes    German Semantic Comparator
# 56             4.0           Yes    German Semantic Comparator
# 57             5.0           Yes    German Semantic Comparator
# 58             6.0           Yes    German Semantic Comparator
# 59             7.0           Yes    German Semantic Comparator
# 60             8.0           Yes    German Semantic Comparator
# 61             9.0           Yes  MultiLang Efficient Embedder
# 62            10.0           Yes  MultiLang Efficient Embedder
# 63            11.0           Yes  MultiLang Efficient Embedder
# 64            12.0           Yes  MultiLang Efficient Embedder
# 65            13.0           Yes  MultiLang Efficient Embedder
# 66            14.0           Yes  MultiLang Efficient Embedder
# 67            15.0           Yes  MultiLang Efficient Embedder
# 68            16.0           Yes  MultiLang Efficient Embedder
# 69            17.0            No    German Semantic Comparator
# 70            18.0            No    German Semantic Comparator
# 71            19.0            No    German Semantic Comparator
# 72            20.0            No    German Semantic Comparator
# 73            21.0            No    German Semantic Comparator
# 74            22.0            No    German Semantic Comparator
# 75            23.0            No    German Semantic Comparator
# 76            24.0            No    German Semantic Comparator
# 77            25.0            No  MultiLang Efficient Embedder
# 78            26.0            No  MultiLang Efficient Embedder
# 79            27.0            No  MultiLang Efficient Embedder
# 80            28.0            No  MultiLang Efficient Embedder
# 81            29.0            No  MultiLang Efficient Embedder
# 82            30.0            No  MultiLang Efficient Embedder
# 83            31.0            No  MultiLang Efficient Embedder
# 84            32.0            No  MultiLang Efficient Embedder
#
#        Algorithm Type                                           Features  \
# 53  Cosine Similarity                                          body_text
# 54  Cosine Similarity                  body_text, advertiser domain name
# 55  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 56  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 57   Faiss Similarity                                          body_text
# 58   Faiss Similarity                  body_text, advertiser domain name
# 59   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 60   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 61  Cosine Similarity                                          body_text
# 62  Cosine Similarity                  body_text, advertiser domain name
# 63  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 64  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 65   Faiss Similarity                                          body_text
# 66   Faiss Similarity                  body_text, advertiser domain name
# 67   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 68   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 69  Cosine Similarity                                          body_text
# 70  Cosine Similarity                  body_text, advertiser domain name
# 71  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 72  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 73   Faiss Similarity                                          body_text
# 74   Faiss Similarity                  body_text, advertiser domain name
# 75   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 76   Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 77  Cosine Similarity                                          body_text
# 78  Cosine Similarity                  body_text, advertiser domain name
# 79  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 80  Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 81   Faiss Similarity                                          body_text
# 82   Faiss Similarity                  body_text, advertiser domain name
# 83   Faiss Similarity   body_text, advertiser domain name, Image Caption
# 84   Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 53                        143.0                23.0                 8.0
# 54                        143.0                24.0                10.0
# 55                        143.0                25.0                10.0
# 56                        143.0                20.0                10.0
# 57                        143.0                23.0                 9.0
# 58                        143.0                25.0                10.0
# 59                        143.0                25.0                10.0
# 60                        143.0                21.0                10.0
# 61                        143.0                 1.0                 0.0
# 62                        143.0                 3.0                 0.0
# 63                        143.0                 2.0                 0.0
# 64                        143.0                 2.0                 0.0
# 65                        143.0                 0.0                 0.0
# 66                        143.0                 2.0                 0.0
# 67                        143.0                 0.0                 0.0
# 68                        143.0                 1.0                 0.0
# 69                        143.0                15.0                 6.0
# 70                        143.0                23.0                 9.0
# 71                        143.0                24.0                 9.0
# 72                        143.0                17.0                 7.0
# 73                        143.0                15.0                 6.0
# 74                        143.0                23.0                 9.0
# 75                        143.0                24.0                10.0
# 76                        143.0                18.0                 7.0
# 77                        143.0                 4.0                 1.0
# 78                        143.0                 2.0                 0.0
# 79                        143.0                 1.0                 1.0
# 80                        143.0                 2.0                 1.0
# 81                        143.0                 3.0                 0.0
# 82                        143.0                 1.0                 0.0
# 83                        143.0                 1.0                 0.0
# 84                        143.0                 2.0                 1.0
#
#     Precision@10  Recall@10  Precision@25  Recall@25              query
# 53           0.8   0.055944          0.92   0.160839  schnäppchen flüge
# 54           1.0   0.069930          0.96   0.167832  schnäppchen flüge
# 55           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 56           1.0   0.069930          0.80   0.139860  schnäppchen flüge
# 57           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 58           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 59           1.0   0.069930          1.00   0.174825  schnäppchen flüge
# 60           1.0   0.069930          0.84   0.146853  schnäppchen flüge
# 61           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 62           0.0   0.000000          0.12   0.020979  schnäppchen flüge
# 63           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 64           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 65           0.0   0.000000          0.00   0.000000  schnäppchen flüge
# 66           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 67           0.0   0.000000          0.00   0.000000  schnäppchen flüge
# 68           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 69           0.6   0.041958          0.60   0.104895  schnäppchen flüge
# 70           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 71           0.9   0.062937          0.96   0.167832  schnäppchen flüge
# 72           0.7   0.048951          0.68   0.118881  schnäppchen flüge
# 73           0.6   0.041958          0.60   0.104895  schnäppchen flüge
# 74           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 75           1.0   0.069930          0.96   0.167832  schnäppchen flüge
# 76           0.7   0.048951          0.72   0.125874  schnäppchen flüge
# 77           0.1   0.006993          0.16   0.027972  schnäppchen flüge
# 78           0.0   0.000000          0.08   0.013986  schnäppchen flüge
# 79           0.1   0.006993          0.04   0.006993  schnäppchen flüge
# 80           0.1   0.006993          0.08   0.013986  schnäppchen flüge
# 81           0.0   0.000000          0.12   0.020979  schnäppchen flüge
# 82           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 83           0.0   0.000000          0.04   0.006993  schnäppchen flüge
# 84           0.1   0.006993          0.08   0.013986  schnäppchen flüge

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
precision_baseline = 0.44 # wein kaufen at 25
recall_baseline = 0.17 # wein kaufen at 25

# %%
precision_semantic_search = data['Precision@25'].to_numpy()
recall_semantic_search = data['Recall@25'].to_numpy()

# %%
recall_semantic_search
# Out:
# array([0.16083916, 0.16783217, 0.17482517, 0.13986014, 0.16083916,
#        0.17482517, 0.17482517, 0.14685315, 0.00699301, 0.02097902,
#        0.01398601, 0.01398601, 0.        , 0.01398601, 0.        ,
#        0.00699301, 0.1048951 , 0.16083916, 0.16783217, 0.11888112,
#        0.1048951 , 0.16083916, 0.16783217, 0.12587413, 0.02797203,
#        0.01398601, 0.00699301, 0.01398601, 0.02097902, 0.00699301,
#        0.00699301, 0.01398601])

# %%
precision_semantic_search
# Out:
# array([0.92, 0.96, 1.  , 0.8 , 0.92, 1.  , 1.  , 0.84, 0.04, 0.12, 0.08,
#        0.08, 0.  , 0.08, 0.  , 0.04, 0.6 , 0.92, 0.96, 0.68, 0.6 , 0.92,
#        0.96, 0.72, 0.16, 0.08, 0.04, 0.08, 0.12, 0.04, 0.04, 0.08])

# %%
plt.figure(figsize=(8, 6))
plt.plot(recall_semantic_search, precision_semantic_search, label='Semantic Search', marker='o')

plt.axhline(y=precision_baseline, color='red', linestyle='-', label='Baseline Elasticsearch')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve Comparison')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Scatter Plot for "Wein Kaufen" with Experiment no. 3 and Cosine Similarity

# %%
import json
import pandas as pd

# Path to your JSON file
file_path = './results/wein_kaufen/top_1425/Experiment_cos_sim_1.json'

# Load JSON data from file
with open(file_path, 'r') as file:
    data1 = json.load(file)

# %%
df = pd.DataFrame(data1)
filtered_df = df[(df['similarity'] > 0.7) & (df['wein_kaufen'])]
filtered_df
# Out:
#     similarity                                 frame_hrefs_parsed  \
# 0     0.845474  [{'advertiser.domain_name': 'vinonia.com'}, {'...
# 1     0.845474  [{'advertiser.domain_name': 'taboola.com'}, {'...
# 2     0.841328  [{'advertiser.domain_name': 'taboola.com'}, {'...
# 6     0.811779  [{'advertiser.domain_name': '20min.ch'}, {'adv...
# 9     0.806986  [{'advertiser.domain_name': '20min.ch'}, {'adv...
# 10    0.806986  [{'advertiser.domain_name': '20min.ch'}, {'adv...
# 12    0.800429  [{'advertiser.domain_name': '20min.ch'}, {'adv...
# 13    0.800429  [{'advertiser.domain_name': '20min.ch'}, {'adv...
# 14    0.795124  [{'advertiser.domain_name': '20min.ch'}, {'adv...
# 19    0.758245  [{'advertiser.domain_name': 'gute-weine.de'}, ...
# 20    0.755025  [{'advertiser.domain_name': 'criteo.com'}, {'a...
# 21    0.747290  [{'advertiser.domain_name': '20min.ch'}, {'adv...
# 22    0.742347  [{'advertiser.domain_name': '20min.ch'}, {'adv...
# 23    0.740528  [{'advertiser.domain_name': 'weinclub.ch'}, {'...
# 24    0.724583  [{'advertiser.domain_name': 'grube.de'}, {'adv...
# 25    0.705794  [{'advertiser.domain_name': 'rindchen.de'}, {'...
#
#                               publisher_name  \
# 0                      https://mirror.co.uk/
# 1                 https://dailyrecord.co.uk/
# 2                     https://express.co.uk/
# 6                      https://www.20min.ch/
# 9                      https://www.20min.ch/
# 10                     https://www.20min.ch/
# 12                     https://www.20min.ch/
# 13                     https://www.20min.ch/
# 14                     https://www.20min.ch/
# 19                         https://vesti.bg/
# 20  https://www.manchestereveningnews.co.uk/
# 21                     https://www.20min.ch/
# 22                     https://www.20min.ch/
# 23          https://www.liverpoolecho.co.uk/
# 24                         https://stern.de/
# 25             https://birminghammail.co.uk/
#
#                                             body_text  screenshot_entropy  \
# 0   TOP Weine auf VINONIA.com | Wein online direkt...            5.048335
# 1   TOP Weine auf VINONIA.com | Wein online direkt...            4.992472
# 2   TOP Weine auf VINONIA.com | Wein online direkt...            3.524967
# 6      Wein & Co\nTagesangebot\nWochenangebot\nReisen            4.523362
# 9      Wein & Co\nWochenangebot\nTagesangebot\nReisen            3.987018
# 10     Wein & Co\nWochenangebot\nTagesangebot\nReisen            4.071444
# 12     Wein & Co\nTagesangebot\nReisen\nWochenangebot            4.057129
# 13     Wein & Co\nTagesangebot\nReisen\nWochenangebot            4.114624
# 14     Wein & Co\nReisen\nWochenangebot\nTagesangebot            4.968802
# 19  Horst Sauer Silvaner E…\n\n\n\n\n\nTenuta San ...            1.711671
# 20  J. B. Becker Riesling Wallufer Walkenberg Kabi...            1.514025
# 21  Wein & Co\nTagesangebot\nWochenangebot\nReisen...            4.651944
# 22  Wein & Co\nReisen\nTagesangebot\nWochenangebot...            4.784746
# 23  ALLESVERLOREN TINTA BAROCCA-SHIRAZ 1704 RED SW...            1.720733
# 24  ANZEIGE\nRevitive DE\nSchwere Beine oder Krämp...            3.293166
# 25  Schlossmühlenhof - "Morge…\n11.93 € / 1 l\n8,9...            2.883295
#
#    screenshot scraper_proxy_name  \
# 0     0_2.png             Berlin
# 1     1_4.png             Vienna
# 2     1_7.png             Vienna
# 6     0_3.png             Zurich
# 9     0_4.png             Zurich
# 10    0_4.png             Zurich
# 12    0_3.png             London
# 13    0_3.png             Zurich
# 14    0_4.png              Sofia
# 19   1_12.png             Berlin
# 20    1_5.png             Berlin
# 21    0_2.png             London
# 22    0_3.png             London
# 23    1_5.png             Zurich
# 24   1_33.png             Berlin
# 25    1_8.png             Berlin
#
#                                            repository        hash_value  \
# 0   /home/adbubble/ad-scraper/operations/adsdata/2...  2f2589f4bdafdbfd
# 1   /home/adbubble/ad-scraper/operations/adsdata/2...  c727f2c6b9976761
# 2   /home/adbubble/ad-scraper/operations/adsdata/2...  70836dc21b2f06a5
# 6   /home/adbubble/ad-scraper/operations/adsdata/2...  0a8ba7e2933e6acb
# 9   /home/adbubble/ad-scraper/operations/adsdata/2...  56fd1db1ed99f5c6
# 10  /home/adbubble/ad-scraper/operations/adsdata/2...  8e8a310d65bd8246
# 12  /home/adbubble/ad-scraper/operations/adsdata/2...  c87d301ac0511bf0
# 13  /home/adbubble/ad-scraper/operations/adsdata/2...  282990713211b573
# 14  /home/adbubble/ad-scraper/operations/adsdata/2...  90356d59d30fea59
# 19  /home/adbubble/ad-scraper/operations/adsdata/2...  23bb7a3632a80201
# 20  /home/adbubble/ad-scraper/operations/adsdata/2...  0daeca544d275580
# 21  /home/adbubble/ad-scraper/operations/adsdata/2...  3fb67101d3e96f4a
# 22  /home/adbubble/ad-scraper/operations/adsdata/2...  4e16bb2a76a97557
# 23  /home/adbubble/ad-scraper/operations/adsdata/2...  d5926651e69d59f4
# 24  /home/adbubble/ad-scraper/operations/adsdata/2...  0bafb70d446b8a9f
# 25  /home/adbubble/ad-scraper/operations/adsdata/2...  3daab77db4da2513
#
#            day  ...                                    ad_creative_url  \
# 0   2023-06-18  ...  http://ads3-d.adbl.io/static/img/2023-06-18/Po...
# 1   2023-05-14  ...  http://ads3-d.adbl.io/static/img/2023-05-14/Po...
# 2   2023-06-15  ...  http://ads3-d.adbl.io/static/img/2023-06-15/Pe...
# 6   2023-06-05  ...  http://ads3-d.adbl.io/static/img/2023-06-05/Mo...
# 9   2023-06-14  ...  http://ads3-d.adbl.io/static/img/2023-06-14/Fi...
# 10  2023-05-18  ...  http://ads3-d.adbl.io/static/img/2023-05-18/Mo...
# 12  2023-06-01  ...  http://ads3-d.adbl.io/static/img/2023-06-01/Pe...
# 13  2023-05-21  ...  http://ads3-d.adbl.io/static/img/2023-05-21/Po...
# 14  2023-05-10  ...  http://ads3-d.adbl.io/static/img/2023-05-10/Fi...
# 19  2023-05-07  ...  http://ads3-d.adbl.io/static/img/2023-05-07/Fi...
# 20  2023-06-01  ...  http://ads3-d.adbl.io/static/img/2023-06-01/Fi...
# 21  2023-05-19  ...  http://ads3-d.adbl.io/static/img/2023-05-19/Pe...
# 22  2023-05-21  ...  http://ads3-d.adbl.io/static/img/2023-05-21/Po...
# 23  2023-05-16  ...  http://ads3-d.adbl.io/static/img/2023-05-16/Po...
# 24  2023-06-29  ...  http://ads3-d.adbl.io/static/img/2023-06-29/Pe...
# 25  2023-06-04  ...  http://ads3-d.adbl.io/static/img/2023-06-04/Fi...
#
#    wein_kaufen guenstiger_Mobilfunktarif  kredit_mit_niedrigen_Zinsen  \
# 0         True                     False                        False
# 1         True                     False                        False
# 2         True                     False                        False
# 6         True                     False                        False
# 9         True                     False                        False
# 10        True                     False                        False
# 12        True                     False                        False
# 13        True                     False                        False
# 14        True                     False                        False
# 19        True                     False                        False
# 20        True                     False                        False
# 21        True                     False                        False
# 22        True                     False                        False
# 23        True                     False                        False
# 24        True                     False                        False
# 25        True                     False                        False
#
#    schnaeppchen_Fluege sample  \
# 0                False   True
# 1                False   True
# 2                False   True
# 6                False   True
# 9                False   True
# 10               False   True
# 12               False   True
# 13               False   True
# 14               False   True
# 19               False   True
# 20               False   True
# 21               False   True
# 22               False   True
# 23               False   True
# 24               False   True
# 25               False   True
#
#                                        predicted_text  \
# 0   Vinonja Wein ouline Vin ONIA.com J Wein online...
# 1   online direkt Abhof kaufen! Weine auf VlnoNIA....
# 2   Wein online VIN NIA OG Undo 1 Vins by Taboola ...
# 6   Wochenangebot Reisen Rocca Rubla 21 Angebot lä...
# 9   Zürich Bern Basel Zentralschweiz Front Bergstu...
# 10  Rioja Reserva 2018 (b́v5cl) Fabrikation Sasssi...
# 12  Cum Laude WIRSINDZUKUNFT Sport Schweiz Zürich ...
# 13  Rioja Reserva 2018 Ukraine. #WIRSINDZUKUNFT Sp...
# 14  LeVolte & Le Serre Nuove The Chocolate Block L...
# 19  6m2 Int. Int. Int. Int. Int. Int. Int. Int. In...
# 20                  8 restaurantes 8 restaurantes Aux
# 21  BaRon DE LEY Mär noch 47% verfügbar!  BaRon DE...
# 22  Wocher Wasn & Co nan Sasssicaia & 7 Tagen abh ...
# 23  Ansbuin Barques in Glas nt éléven tief Ansbuin...
# 24  Chime Généne Généne AutoScour24 DE 26 Quane Be...
# 25  Torrevent Azienda Azienda Büenz Aexand Azienda...
#
#                                      image_caption_en  \
# 0   a close up of a wine glass with a wine bottle ...
# 1   a close up of a wine glass with a wine bottle ...
# 2     a close up of a book with a glass of wine on it
# 6   a close up of a website page with a bunch of b...
# 9   arafed image of a woman in a hat and sunglasse...
# 10  a close up of a website page with a bunch of b...
# 12  a close up of a website page with a bunch of b...
# 13  a close up of a website page with a bunch of b...
# 14  a close up of a bunch of bottles of wine on a ...
# 19  a close up of a row of different colored baseb...
# 20  three different types of toothbrushes are line...
# 21     a close up of three bottles of wine on a table
# 22  a close up of a cell phone with a bunch of win...
# 23  a close up of a bottle of wine with a bunch of...
# 24  several different types of wine bottles and a ...
# 25   a close up of a bunch of wine bottles on a table
#
#                                      image_caption_de  \
# 0   eine Nahaufnahme eines Weinglases mit einer We...
# 1   eine Nahaufnahme eines Weinglases mit einer We...
# 2   eine Nahaufnahme eines Buches mit einem Glas W...
# 6   eine Nahaufnahme einer Website-Seite mit einem...
# 9   arafed Bild einer Frau in einem Hut und Sonnen...
# 10  eine Nahaufnahme einer Website-Seite mit einem...
# 12  eine Nahaufnahme einer Website-Seite mit einem...
# 13  eine Nahaufnahme einer Website-Seite mit einem...
# 14  eine Nahaufnahme einer Flasche Wein auf einem ...
# 19  eine Nahaufnahme einer Reihe von verschiedenen...
# 20  drei verschiedene Arten von Zahnbürsten sind i...
# 21  eine Nahaufnahme von drei Flaschen Wein auf ei...
# 22  eine Nahaufnahme eines Handys mit einem Haufen...
# 23  eine Nahaufnahme einer Flasche Wein mit einem ...
# 24  verschiedene Arten von Weinflaschen und ein Au...
# 25  eine Nahaufnahme eines Bündels Weinflaschen au...
#
#                                  combined_description
# 0   VINONIA - Der Wein Marktplatz! - Kaufen Sie on...
# 1   Taboola is the world's leading discovery & nat...
# 2   Taboola is the world's leading discovery & nat...
# 6   20 Minuten News bietet dir 24/7 aktuelle Nachr...
# 9   20 Minuten News bietet dir 24/7 aktuelle Nachr...
# 10  20 Minuten News bietet dir 24/7 aktuelle Nachr...
# 12  20 Minuten News bietet dir 24/7 aktuelle Nachr...
# 13  20 Minuten News bietet dir 24/7 aktuelle Nachr...
# 14  20 Minuten News bietet dir 24/7 aktuelle Nachr...
# 19  Premium Weine entdecken und online kaufen bei ...
# 20  Activate the world’s largest set of commerce d...
# 21  20 Minuten News bietet dir 24/7 aktuelle Nachr...
# 22  20 Minuten News bietet dir 24/7 aktuelle Nachr...
# 23  Entdecken Sie die besten Weine zu attraktiven ...
# 24  Alles rund um Forst, Jagd, Outdoor, Garten & F...
# 25  Über 1000 Weine online Kaufen. Rotwein, Weißwe...
#
# [16 rows x 25 columns]

# %%
import matplotlib.pyplot as plt1
import random


# Extracting data for the plot
x_values = []  # This will store cosine similarity values
y_values = []  # This will store random values for scattering
colors = []    # This will store color values

max_similarity = 0

for obj in data1:
    cosine_similarity = obj.get('similarity', 0)
    wein_kaufen = obj['wein_kaufen']
    max_similarity = max(max_similarity, cosine_similarity) 
    x_values.append(cosine_similarity)
    y_values.append(random.uniform(0, 1) if wein_kaufen else random.uniform(-1, 0))  # Random values for true/false
    colors.append('green' if wein_kaufen else 'blue')  # Yellow for "wein_kaufen" = true, blue for false

# Add the specific query with a large red circle
x_query = [max_similarity]  # Maximum similarity value
y_query = [random.uniform(0, 1)]

# Creating the scatter plot
plt1.figure(figsize=(10, 6))
plt1.scatter(x_values, y_values, c=colors, label='relevant Ads')
plt1.scatter(x_query, y_query, c='red', s=100, label='Query "wein kaufen"')  # Larger red circle for the specific query
plt1.xlabel('Cosine Similarity')
plt1.ylabel('Random Scatter (Wein Kaufen)')
plt1.title('Scatter Plot for "Wein Kaufen" Query')
plt1.legend()
plt1.grid(True)
#plt1.show()

# %% [markdown]
# # Scatter Plot for "Wein Kaufen" with Experiment no. 3 and Faiss Similarity

# %%
import json

# Path to your JSON file
file_path = './results/wein_kaufen/top_1425/Experiment_faiss_similarity.json'

# Load JSON data from file
with open(file_path, 'r') as file:
    data2 = json.load(file)

# %%
import matplotlib.pyplot as plt2
import random


# Extracting data for the plot
x_wein_kaufen = []  # Distances for "wein_kaufen" = true
x_other_ads = []  # Distances for "wein_kaufen" = false
y_wein_kaufen = []  # Y-values for "wein_kaufen" = true (for scattering)
y_other_ads = []    # This will store color values

min_distance = float('inf')

for obj in data2:
    distance = obj.get('similarity', 0)
    min_distance = min(min_distance, distance)
    wein_kaufen = obj['wein_kaufen']

    if wein_kaufen:
        x_wein_kaufen.append(distance)
        y_wein_kaufen.append(random.uniform(0, 1))  # Random scatter close to 0
    else:
        x_other_ads.append(distance)
        y_other_ads.append(random.uniform(-1, 0))

# Add the specific query
x_query = [min_distance]
y_query = [random.uniform(0, 1)]  # Place it centrally on the Y-axis

# Plotting
plt2.figure(figsize=(10, 6))
plt2.scatter(x_wein_kaufen, y_wein_kaufen, color='green', label='relevant Ads')
plt2.scatter(x_other_ads, y_other_ads, color='blue', label='not relevant Ads')
plt2.scatter(x_query, y_query, color='red', s=100, label='Query "Wein Kaufen"', marker='*')  # Star marker for the query

plt2.xlabel('Euclidean Distance')
plt2.ylabel('Random Scatter')
plt2.title('Scatter Plot for "Wein Kaufen" Query')
plt2.legend()
plt2.grid(True)
plt2.show()

# %% [markdown]
# # Scatter Plot for "Wein Kaufen" with Experiment no. 3 and Euclidean Distance

# %%
import json

# Path to your JSON file
file_path = './results/wein_kaufen/top_1425/Experiment_euc_dist_2.json'

# Load JSON data from file
with open(file_path, 'r') as file:
    data3 = json.load(file)

# %%
import matplotlib.pyplot as plt3
import random


# Extracting data for the plot
x_wein_kaufen = []  # Distances for "wein_kaufen" = true
x_other_ads = []  # Distances for "wein_kaufen" = false
y_wein_kaufen = []  # Y-values for "wein_kaufen" = true (for scattering)
y_other_ads = []    # This will store color values

min_distance = float('inf')

for obj in data3:
    distance = obj.get('similarity', 0)
    min_distance = min(min_distance, distance)
    wein_kaufen = obj['wein_kaufen']

    if wein_kaufen:
        x_wein_kaufen.append(distance)
        y_wein_kaufen.append(random.uniform(0, 1))  # Random scatter close to 0
    else:
        x_other_ads.append(distance)
        y_other_ads.append(random.uniform(-1, 0))

# Add the specific query
x_query = [min_distance]
y_query = [random.uniform(0, 1)]  # Place it centrally on the Y-axis

# Plotting
plt3.figure(figsize=(10, 6))
plt3.scatter(x_wein_kaufen, y_wein_kaufen, color='green', label='relevant Ads')
plt3.scatter(x_other_ads, y_other_ads, color='blue', label='not relevant Ads')
plt3.scatter(x_query, y_query, color='red', s=100, label='Query "Wein Kaufen"', marker='*')  # Star marker for the query

plt3.xlabel('Euclidean Distance')
plt3.ylabel('Random Scatter')
plt3.title('Scatter Plot for "Wein Kaufen" Query')
plt3.legend()
plt3.grid(True)
plt3.show()

# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /Users/maykalmorjan/anaconda3/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /Users/maykalmorjan/anaconda3/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/maykalmorjan/anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maykalmorjan/anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/maykalmorjan/anaconda3/lib/python3.11/site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maykalmorjan/anaconda3/lib/python3.11/site-packages (from requests) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in /Users/maykalmorjan/anaconda3/lib/python3.11/site-packages (from beautifulsoup4) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

def get_meta_description(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code

        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find the meta description tag
        meta_description_tag = soup.find('meta', attrs={'name': 'description'})
        
        if meta_description_tag:
            return meta_description_tag.get('content')
        else:
            return "No description meta tag found"
    except requests.RequestException as e:
        return str(e)

# URL to scrape
url = 'https://immobilie-richtig-verkaufen.ch'

# Get and print the meta description
description = get_meta_description(url)
print(description)
# Out:
# No description meta tag found

# %% [markdown]
# # plot how the data cleaning effects on the relevant results

# %%
import matplotlib.pyplot as plt
data = combined_df[(combined_df['query'] == 'wein kaufen') ]

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 0                1                Yes    German Semantic Comparator
# 1                2                Yes    German Semantic Comparator
# 2                3                Yes    German Semantic Comparator
# 3                4                Yes    German Semantic Comparator
# 4                5                Yes    German Semantic Comparator
# 5                6                Yes    German Semantic Comparator
# 6                7                Yes    German Semantic Comparator
# 7                8                Yes    German Semantic Comparator
# 8                9                Yes  MultiLang Efficient Embedder
# 9               10                Yes  MultiLang Efficient Embedder
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# 13              14                Yes  MultiLang Efficient Embedder
# 14              15                Yes  MultiLang Efficient Embedder
# 15              16                Yes  MultiLang Efficient Embedder
# 16              17                 No    German Semantic Comparator
# 17              18                 No    German Semantic Comparator
# 18              19                 No    German Semantic Comparator
# 19              20                 No    German Semantic Comparator
# 20              21                 No    German Semantic Comparator
# 21              22                 No    German Semantic Comparator
# 22              23                 No    German Semantic Comparator
# 23              24                 No    German Semantic Comparator
# 24              25                 No  MultiLang Efficient Embedder
# 25              26                 No  MultiLang Efficient Embedder
# 26              27                 No  MultiLang Efficient Embedder
# 27              28                 No  MultiLang Efficient Embedder
# 28              29                 No  MultiLang Efficient Embedder
# 29              30                 No  MultiLang Efficient Embedder
# 30              31                 No  MultiLang Efficient Embedder
# 31              32                 No  MultiLang Efficient Embedder
# 32              33                Yes    German Semantic Comparator
# 33              34                Yes    German Semantic Comparator
# 34              35                Yes  MultiLang Efficient Embedder
# 35              36                Yes  MultiLang Efficient Embedder
# 36              37                 No    German Semantic Comparator
# 37              38                 No    German Semantic Comparator
# 38              39                 No  MultiLang Efficient Embedder
# 39              40                 No  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features  \
# 0    Cosine Similarity                                          body_text
# 1    Cosine Similarity                  body_text, advertiser domain name
# 2    Cosine Similarity   body_text, advertiser domain name, Image Caption
# 3    Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 4   Euclidean Distance                                          body_text
# 5   Euclidean Distance                  body_text, advertiser domain name
# 6   Euclidean Distance   body_text, advertiser domain name, Image Caption
# 7   Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 8    Cosine Similarity                                          body_text
# 9    Cosine Similarity                  body_text, advertiser domain name
# 10   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 11   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 12  Euclidean Distance                                          body_text
# 13  Euclidean Distance                  body_text, advertiser domain name
# 14  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 15  Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 16   Cosine Similarity                                          body_text
# 17   Cosine Similarity                  body_text, advertiser domain name
# 18   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 19   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 20  Euclidean Distance                                          body_text
# 21  Euclidean Distance                  body_text, advertiser domain name
# 22  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 23  Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 24   Cosine Similarity                                          body_text
# 25   Cosine Similarity                  body_text, advertiser domain name
# 26   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 27   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 28  Euclidean Distance                                          body_text
# 29  Euclidean Distance                  body_text, advertiser domain name
# 30  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 31  Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 32   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 33    Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 34   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 35    Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 36   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 37    Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 38   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 39    Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 0                            63                  16                   3
# 1                            63                  21                   6
# 2                            63                  20                   7
# 3                            63                  19                   6
# 4                            63                  16                   5
# 5                            63                  21                   6
# 6                            63                  19                   7
# 7                            63                  19                   6
# 8                            63                  11                   7
# 9                            63                   6                   2
# 10                           63                   7                   5
# 11                           63                  13                   8
# 12                           63                  10                   7
# 13                           63                   2                   0
# 14                           63                   4                   2
# 15                           63                   9                   5
# 16                           63                  15                   4
# 17                           63                  20                   6
# 18                           63                  20                   7
# 19                           63                  21                   7
# 20                           63                  15                   4
# 21                           63                  15                   8
# 22                           63                  19                   8
# 23                           63                  20                   7
# 24                           63                  14                   1
# 25                           63                  20                   6
# 26                           63                  24                   9
# 27                           63                  24                  10
# 28                           63                   2                   1
# 29                           63                  14                   3
# 30                           63                  20                   9
# 31                           63                  21                   8
# 32                           63                  20                   7
# 33                           63                  20                   7
# 34                           63                  10                   5
# 35                           63                   1                   0
# 36                           63                  22                   9
# 37                           63                  24                   9
# 38                           63                  19                   8
# 39                           63                  18                   8
#
#     Precision@10  Recall@10  Precision@25  Recall@25        query
# 0            0.3   0.047619          0.64   0.253968  wein kaufen
# 1            0.6   0.095238          0.84   0.333333  wein kaufen
# 2            0.7   0.111111          0.80   0.317460  wein kaufen
# 3            0.6   0.095238          0.76   0.301587  wein kaufen
# 4            0.5   0.079365          0.64   0.253968  wein kaufen
# 5            0.6   0.095238          0.84   0.333333  wein kaufen
# 6            0.7   0.111111          0.76   0.301587  wein kaufen
# 7            0.6   0.095238          0.76   0.301587  wein kaufen
# 8            0.7   0.111111          0.44   0.174603  wein kaufen
# 9            0.2   0.031746          0.24   0.095238  wein kaufen
# 10           0.5   0.079365          0.28   0.111111  wein kaufen
# 11           0.8   0.126984          0.52   0.206349  wein kaufen
# 12           0.7   0.111111          0.40   0.158730  wein kaufen
# 13           0.0   0.000000          0.08   0.031746  wein kaufen
# 14           0.2   0.031746          0.16   0.063492  wein kaufen
# 15           0.5   0.079365          0.36   0.142857  wein kaufen
# 16           0.4   0.063492          0.60   0.238095  wein kaufen
# 17           0.6   0.095238          0.80   0.317460  wein kaufen
# 18           0.7   0.111111          0.80   0.317460  wein kaufen
# 19           0.7   0.111111          0.84   0.333333  wein kaufen
# 20           0.4   0.063492          0.60   0.238095  wein kaufen
# 21           0.8   0.126984          0.60   0.238095  wein kaufen
# 22           0.8   0.126984          0.76   0.301587  wein kaufen
# 23           0.7   0.111111          0.80   0.317460  wein kaufen
# 24           0.1   0.015873          0.56   0.222222  wein kaufen
# 25           0.6   0.095238          0.80   0.317460  wein kaufen
# 26           0.9   0.142857          0.96   0.380952  wein kaufen
# 27           1.0   0.158730          0.96   0.380952  wein kaufen
# 28           0.1   0.015873          0.08   0.031746  wein kaufen
# 29           0.3   0.047619          0.56   0.222222  wein kaufen
# 30           0.9   0.142857          0.80   0.317460  wein kaufen
# 31           0.8   0.126984          0.84   0.333333  wein kaufen
# 32           0.7   0.111111          0.80   0.317460  wein kaufen
# 33           0.7   0.111111          0.80   0.317460  wein kaufen
# 34           0.5   0.079365          0.40   0.158730  wein kaufen
# 35           0.0   0.000000          0.04   0.015873  wein kaufen
# 36           0.9   0.142857          0.88   0.349206  wein kaufen
# 37           0.9   0.142857          0.96   0.380952  wein kaufen
# 38           0.8   0.126984          0.76   0.301587  wein kaufen
# 39           0.8   0.126984          0.72   0.285714  wein kaufen

# %%
aggregated_data_at_25 = data.groupby('Data Preprocessing')['Relevant no. of 25'].mean()  
aggregated_data_at_10 = data.groupby('Data Preprocessing')['Relevant no. of 10'].mean()  
df_25 = aggregated_data_at_25.reset_index(name='Relevant no. of 25')
df_10 = aggregated_data_at_10.reset_index(name='Relevant no. of 10')

# Merge the two DataFrames on the 'Data Preprocessing' column
merged_data = pd.merge(df_25, df_10, on='Data Preprocessing')

# Plotting
ax = merged_data.plot(x='Data Preprocessing', y='Relevant no. of 25', kind='bar', color='blue', position=0, width=0.4, label='Relevant no. of 25')
merged_data.plot(x='Data Preprocessing', y='Relevant no. of 10', kind='bar', color='red', position=1, width=0.4, label='Relevant no. of 10', ax=ax)

# Customizing the plot
plt.xlabel('Data Preprocessing')
plt.ylabel('Average Relevant Number')
plt.title('Impact of Data Preprocessing on Relevant Ads')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
aggregated_data_at_25 = data.groupby('Model Type')['Relevant no. of 25'].mean()  # or use another function like mean() if more appropriate
aggregated_data_at_10 = data.groupby('Model Type')['Relevant no. of 10'].mean()  # or use another function like mean() if more appropriate

df_25 = aggregated_data_at_25.reset_index(name='Relevant no. of 25')
df_10 = aggregated_data_at_10.reset_index(name='Relevant no. of 10')

# Merge the two DataFrames on the 'Model Type' column
merged_data = pd.merge(df_25, df_10, on='Model Type')

# Plotting
ax = merged_data.plot(x='Model Type', y='Relevant no. of 25', kind='bar', color='blue', position=0, width=0.4, label='Relevant no. of 25')
merged_data.plot(x='Model Type', y='Relevant no. of 10', kind='bar', color='red', position=1, width=0.4, label='Relevant no. of 10', ax=ax)

# Customizing the plot
plt.xlabel('Model Type')
plt.ylabel('Average Relevant Number')
plt.title('Impact of Model Type on Relevant Ads')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
aggregated_data_at_25 = data.groupby('Algorithm Type')['Relevant no. of 25'].mean()  # or use another function like mean() if more appropriate
aggregated_data_at_10 = data.groupby('Algorithm Type')['Relevant no. of 10'].mean()  # or use another function like mean() if more appropriate

df_25 = aggregated_data_at_25.reset_index(name='Relevant no. of 25')
df_10 = aggregated_data_at_10.reset_index(name='Relevant no. of 10')

# Merge the two DataFrames on the 'Algorithm Type' column
merged_data = pd.merge(df_25, df_10, on='Algorithm Type')

# Plotting
ax = merged_data.plot(x='Algorithm Type', y='Relevant no. of 25', kind='bar', color='blue', position=0, width=0.4, label='Relevant no. of 25')
merged_data.plot(x='Algorithm Type', y='Relevant no. of 10', kind='bar', color='red', position=1, width=0.4, label='Relevant no. of 10', ax=ax)

# Customizing the plot
plt.xlabel('Algorithm Type')
plt.ylabel('Average Relevant Number')
plt.title('Impact of Algorithm Type on Relevant Ads')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
data
# Out:
#     Experiment no. Data Preprocessing                    Model Type  \
# 0                1                Yes    German Semantic Comparator
# 1                2                Yes    German Semantic Comparator
# 2                3                Yes    German Semantic Comparator
# 3                4                Yes    German Semantic Comparator
# 4                5                Yes    German Semantic Comparator
# 5                6                Yes    German Semantic Comparator
# 6                7                Yes    German Semantic Comparator
# 7                8                Yes    German Semantic Comparator
# 8                9                Yes  MultiLang Efficient Embedder
# 9               10                Yes  MultiLang Efficient Embedder
# 10              11                Yes  MultiLang Efficient Embedder
# 11              12                Yes  MultiLang Efficient Embedder
# 12              13                Yes  MultiLang Efficient Embedder
# 13              14                Yes  MultiLang Efficient Embedder
# 14              15                Yes  MultiLang Efficient Embedder
# 15              16                Yes  MultiLang Efficient Embedder
# 16              17                 No    German Semantic Comparator
# 17              18                 No    German Semantic Comparator
# 18              19                 No    German Semantic Comparator
# 19              20                 No    German Semantic Comparator
# 20              21                 No    German Semantic Comparator
# 21              22                 No    German Semantic Comparator
# 22              23                 No    German Semantic Comparator
# 23              24                 No    German Semantic Comparator
# 24              25                 No  MultiLang Efficient Embedder
# 25              26                 No  MultiLang Efficient Embedder
# 26              27                 No  MultiLang Efficient Embedder
# 27              28                 No  MultiLang Efficient Embedder
# 28              29                 No  MultiLang Efficient Embedder
# 29              30                 No  MultiLang Efficient Embedder
# 30              31                 No  MultiLang Efficient Embedder
# 31              32                 No  MultiLang Efficient Embedder
# 32              33                Yes    German Semantic Comparator
# 33              34                Yes    German Semantic Comparator
# 34              35                Yes  MultiLang Efficient Embedder
# 35              36                Yes  MultiLang Efficient Embedder
# 36              37                 No    German Semantic Comparator
# 37              38                 No    German Semantic Comparator
# 38              39                 No  MultiLang Efficient Embedder
# 39              40                 No  MultiLang Efficient Embedder
#
#         Algorithm Type                                           Features  \
# 0    Cosine Similarity                                          body_text
# 1    Cosine Similarity                  body_text, advertiser domain name
# 2    Cosine Similarity   body_text, advertiser domain name, Image Caption
# 3    Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 4   Euclidean Distance                                          body_text
# 5   Euclidean Distance                  body_text, advertiser domain name
# 6   Euclidean Distance   body_text, advertiser domain name, Image Caption
# 7   Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 8    Cosine Similarity                                          body_text
# 9    Cosine Similarity                  body_text, advertiser domain name
# 10   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 11   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 12  Euclidean Distance                                          body_text
# 13  Euclidean Distance                  body_text, advertiser domain name
# 14  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 15  Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 16   Cosine Similarity                                          body_text
# 17   Cosine Similarity                  body_text, advertiser domain name
# 18   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 19   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 20  Euclidean Distance                                          body_text
# 21  Euclidean Distance                  body_text, advertiser domain name
# 22  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 23  Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 24   Cosine Similarity                                          body_text
# 25   Cosine Similarity                  body_text, advertiser domain name
# 26   Cosine Similarity   body_text, advertiser domain name, Image Caption
# 27   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 28  Euclidean Distance                                          body_text
# 29  Euclidean Distance                  body_text, advertiser domain name
# 30  Euclidean Distance   body_text, advertiser domain name, Image Caption
# 31  Euclidean Distance  body_text, advertiser domain name, Image Capti...
# 32   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 33    Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 34   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 35    Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 36   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 37    Faiss Similarity  body_text, advertiser domain name, Image Capti...
# 38   Cosine Similarity  body_text, advertiser domain name, Image Capti...
# 39    Faiss Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 0                            63                  16                   3
# 1                            63                  21                   6
# 2                            63                  20                   7
# 3                            63                  19                   6
# 4                            63                  16                   5
# 5                            63                  21                   6
# 6                            63                  19                   7
# 7                            63                  19                   6
# 8                            63                  11                   7
# 9                            63                   6                   2
# 10                           63                   7                   5
# 11                           63                  13                   8
# 12                           63                  10                   7
# 13                           63                   2                   0
# 14                           63                   4                   2
# 15                           63                   9                   5
# 16                           63                  15                   4
# 17                           63                  20                   6
# 18                           63                  20                   7
# 19                           63                  21                   7
# 20                           63                  15                   4
# 21                           63                  15                   8
# 22                           63                  19                   8
# 23                           63                  20                   7
# 24                           63                  14                   1
# 25                           63                  20                   6
# 26                           63                  24                   9
# 27                           63                  24                  10
# 28                           63                   2                   1
# 29                           63                  14                   3
# 30                           63                  20                   9
# 31                           63                  21                   8
# 32                           63                  20                   7
# 33                           63                  20                   7
# 34                           63                  10                   5
# 35                           63                   1                   0
# 36                           63                  22                   9
# 37                           63                  24                   9
# 38                           63                  19                   8
# 39                           63                  18                   8
#
#     Precision@10  Recall@10  Precision@25  Recall@25        query
# 0            0.3   0.047619          0.64   0.253968  wein kaufen
# 1            0.6   0.095238          0.84   0.333333  wein kaufen
# 2            0.7   0.111111          0.80   0.317460  wein kaufen
# 3            0.6   0.095238          0.76   0.301587  wein kaufen
# 4            0.5   0.079365          0.64   0.253968  wein kaufen
# 5            0.6   0.095238          0.84   0.333333  wein kaufen
# 6            0.7   0.111111          0.76   0.301587  wein kaufen
# 7            0.6   0.095238          0.76   0.301587  wein kaufen
# 8            0.7   0.111111          0.44   0.174603  wein kaufen
# 9            0.2   0.031746          0.24   0.095238  wein kaufen
# 10           0.5   0.079365          0.28   0.111111  wein kaufen
# 11           0.8   0.126984          0.52   0.206349  wein kaufen
# 12           0.7   0.111111          0.40   0.158730  wein kaufen
# 13           0.0   0.000000          0.08   0.031746  wein kaufen
# 14           0.2   0.031746          0.16   0.063492  wein kaufen
# 15           0.5   0.079365          0.36   0.142857  wein kaufen
# 16           0.4   0.063492          0.60   0.238095  wein kaufen
# 17           0.6   0.095238          0.80   0.317460  wein kaufen
# 18           0.7   0.111111          0.80   0.317460  wein kaufen
# 19           0.7   0.111111          0.84   0.333333  wein kaufen
# 20           0.4   0.063492          0.60   0.238095  wein kaufen
# 21           0.8   0.126984          0.60   0.238095  wein kaufen
# 22           0.8   0.126984          0.76   0.301587  wein kaufen
# 23           0.7   0.111111          0.80   0.317460  wein kaufen
# 24           0.1   0.015873          0.56   0.222222  wein kaufen
# 25           0.6   0.095238          0.80   0.317460  wein kaufen
# 26           0.9   0.142857          0.96   0.380952  wein kaufen
# 27           1.0   0.158730          0.96   0.380952  wein kaufen
# 28           0.1   0.015873          0.08   0.031746  wein kaufen
# 29           0.3   0.047619          0.56   0.222222  wein kaufen
# 30           0.9   0.142857          0.80   0.317460  wein kaufen
# 31           0.8   0.126984          0.84   0.333333  wein kaufen
# 32           0.7   0.111111          0.80   0.317460  wein kaufen
# 33           0.7   0.111111          0.80   0.317460  wein kaufen
# 34           0.5   0.079365          0.40   0.158730  wein kaufen
# 35           0.0   0.000000          0.04   0.015873  wein kaufen
# 36           0.9   0.142857          0.88   0.349206  wein kaufen
# 37           0.9   0.142857          0.96   0.380952  wein kaufen
# 38           0.8   0.126984          0.76   0.301587  wein kaufen
# 39           0.8   0.126984          0.72   0.285714  wein kaufen

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Calculate the mean for the relevant numbers at 25 and 10
aggregated_data_at_25 = data.groupby('Features')['Relevant no. of 25'].mean()
aggregated_data_at_10 = data.groupby('Features')['Relevant no. of 10'].mean()

# Reset the index to make 'Features' a column again
df_25 = aggregated_data_at_25.reset_index(name='Relevant no. of 25')
df_10 = aggregated_data_at_10.reset_index(name='Relevant no. of 10')

# Merge the two DataFrames on the 'Features' column
merged_data = pd.merge(df_25, df_10, on='Features')

# Create a mapping for the feature names to 'feature_1', 'feature_2', ...
feature_mapping = {feature: f'feature_set_{i+1}' for i, feature in enumerate(merged_data['Features'].unique())}

# Apply the mapping to the 'Features' column
merged_data['Features'] = merged_data['Features'].map(feature_mapping)

# Plotting
ax = merged_data.plot(x='Features', y='Relevant no. of 25', kind='bar', color='blue', position=0, width=0.4, label='Relevant no. of 25')
merged_data.plot(x='Features', y='Relevant no. of 10', kind='bar', color='red', position=1, width=0.4, label='Relevant no. of 10', ax=ax)

# Customizing the plot
plt.xlabel('Features')
plt.ylabel('Average Relevant Number')
plt.title('Impact of Features on Relevant Ads')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
import pandas as pd

file_path = "./sample/ground_truth.json"

ads = pd.read_json(file_path)

ads_body_text = ads['body_text']

ads_body_text
# Out:
# 0       Sommelier gibt zu: Alle Weine schmecken exakt ...
# 1       Mountainbiken in der Steiermark: ein Fest für ...
# 2       Das Online-Girokonto\nFür alle, die ihre Bankg...
# 3       Der Privatkredit\nEin Kredit, der so spontan i...
# 4       Endlich! Schnellstart ins Programmieren mit Py...
#                               ...
# 1420    Wien - Korfu\n41 €\nJetzt buchen\nWien - Malé\...
# 1421    Wien - Korfu\n€44\nJetzt buchen\nWien -\nVened...
# 1422    -20%\nHAMMER\n€ 68.58\nAlles für deine Tour de...
# 1423    Finde Günstige Flüge\ncheckfelix\nWien - Banja...
# 1424    Fair Fashion\nModerne Designs, elegante Klassi...
# Name: body_text, Length: 1425, dtype: object

# %%
word_counts = ads_body_text.apply(lambda x: len(str(x).split()))

# Calculate the average number of words
average_word_count = word_counts.mean()

# %%
average_word_count
# Out:
# 18.183859649122805

# %%
data = combined_df[(combined_df['query'] == 'schnäppchen flüge') ]
best_experiments = data[(data["Data Preprocessing"] == 'No') &
                       (data["Model Type"] == 'German Semantic Comparator') &
                       (data["Algorithm Type"] == 'Cosine Similarity') ]

# %%
best_experiments
# Out:
#     Experiment no. Data Preprocessing                  Model Type  \
# 88              17                 No  German Semantic Comparator
# 89              18                 No  German Semantic Comparator
# 90              19                 No  German Semantic Comparator
# 91              20                 No  German Semantic Comparator
#
#        Algorithm Type                                           Features  \
# 88  Cosine Similarity                                          body_text
# 89  Cosine Similarity                  body_text, advertiser domain name
# 90  Cosine Similarity   body_text, advertiser domain name, Image Caption
# 91  Cosine Similarity  body_text, advertiser domain name, Image Capti...
#
#     Total no. of Relevant in db  Relevant no. of 25  Relevant no. of 10  \
# 88                          143                  15                   6
# 89                          143                  23                   9
# 90                          143                  24                   9
# 91                          143                  17                   7
#
#     Precision@10  Recall@10  Precision@25  Recall@25              query
# 88           0.6   0.041958          0.60   0.104895  schnäppchen flüge
# 89           0.9   0.062937          0.92   0.160839  schnäppchen flüge
# 90           0.9   0.062937          0.96   0.167832  schnäppchen flüge
# 91           0.7   0.048951          0.68   0.118881  schnäppchen flüge
